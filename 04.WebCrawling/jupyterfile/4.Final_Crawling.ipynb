# %% [markdown]
# ### Zigbang 원룸 매물 데이터 수집
#
# #### Process
#     - 동이름으로 위도 경도 구하기
#     - 위도 경도로 geohash 알아내기
#     - geohash로 매물 아이디 가져오기
#     - 매물 아이디로 매물 정보 가져오기

# %% [markdown]
# #### 0. 라이브러리 불러오기

# %%
import pandas as pd
import requests

# %% [markdown]
# #### 1. 동이름으로 위도 경도 구하기

# %%
addr = '망원동'
url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸'

response = requests.get(url)
print(response)

response.text
# Out:
# <Response [200]>
# '{"success":true,"code":"200","items":[{"id":4002,"type":"address","name":"망원동","hint":"","description":"서울특별시 마포구 망원동","lat":37.556785583496094,"lng":126.9013442993164,"zoom":5,"polygon":[],"_score":null,"_source":{"name_length":3,"local1":"서울시","local2":"마포구","local3":"망원동","web_level":15,"web_lat":37.556785583496094,"web_lng":126.9013442993164,"app_level":15,"app_lat":37.556785583496094,"app_lng":126.9013442993164,"법정동코드":"1144012300"},"zoom_level":{"google":15,"daum":4},"zoom_level_v2":{"app":5,"web":4}}],"next":null,"limit":0}'

# %%
# 동이 여러개일경우에, 여러개 뜬다.
# 일단 편의를 위해 첫번째 값을 가져온다고 해보자.

data = response.json()['items'][0]
data
# Out:
# {'id': 4002,
#  'type': 'address',
#  'name': '망원동',
#  'hint': '',
#  'description': '서울특별시 마포구 망원동',
#  'lat': 37.556785583496094,
#  'lng': 126.9013442993164,
#  'zoom': 5,
#  'polygon': [],
#  '_score': None,
#  '_source': {'name_length': 3,
#   'local1': '서울시',
#   'local2': '마포구',
#   'local3': '망원동',
#   'web_level': 15,
#   'web_lat': 37.556785583496094,
#   'web_lng': 126.9013442993164,
#   'app_level': 15,
#   'app_lat': 37.556785583496094,
#   'app_lng': 126.9013442993164,
#   '법정동코드': '1144012300'},
#  'zoom_level': {'google': 15, 'daum': 4},
#  'zoom_level_v2': {'app': 5, 'web': 4}}

# %%
lat, lng = data['lat'], data['lng']
lat, lng
# Out:
# (37.556785583496094, 126.9013442993164)

# %% [markdown]
# #### 2. 위도 경도로 geohash 알아내기
# - geohash2 package 설치

# %%
# !pip install geohash2
# Out:
# Requirement already satisfied: geohash2 in c:\users\user\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: docutils>=0.3 in c:\users\user\anaconda3\lib\site-packages (from geohash2) (0.18.1)

# %%
import geohash2

# %%
# presicion : 영역 크기 : 커질수록 영역이 작아진다.
geohash = geohash2.encode(lat, lng, precision=5)
geohash
# Out:
# 'wydjx'

# %% [markdown]
# #### 3. geohash로 매물 아이디 가져오기

# %%
url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸'

response = requests.get(url)
print(response)

response.text
# Out:
# <Response [200]>
# '{"clusters":[],"items":[{"lat":37.52957896797038,"lng":126.89981539511652,"item_id":37623131},{"lat":37.52910255446707,"lng":126.90042739831257,"item_id":37685329},{"lat":37.529597911464876,"lng":126.90041315587592,"item_id":37699264},{"lat":37.5295886669088,"lng":126.89958018247103,"item_id":37828417},{"lat":37.52960743464446,"lng":126.89758317220698,"item_id":37595863},{"lat":37.529116962216044,"lng":126.8969522519338,"item_id":37812771},{"lat":37.529692492203175,"lng":126.90731180728964,"item_id":37594373},{"lat":37.52975469741576,"lng":126.8994820019441,"item_id":37779193},{"lat":37.529807146389054,"lng":126.89735191205774,"item_id":37681821},{"lat":37.52978662830859,"lng":126.89796335208214,"item_id":37789981},{"lat":37.52930348427087,"lng":126.89734045105382,"item_id":37812120},{"lat":37.52939719075808,"lng":126.90756551290187,"item_id":37591840},{"lat":37.5299016829542,"lng":126.90755322990103,"item_id":37647361},{"lat":37.529375000863716,"lng":126.90690372443841,"item_id":37776332},{"lat":37.529873127274925,"lng":126.90757838095746,"item_id":37821042},{"lat":37.52988432221632,"lng":126.90756715078479,"item_id":37822875},{"lat":37.52940096495681,"lng":126.90754220614008,"item_id":37822954},{"lat":37.52990807351831,"lng":126.90692815645842,"item_id":37830915},{"lat":37.529879472486016,"lng":126.90755112938227,"item_id":37831419},{"lat":37.52939267559536,"lng":126.9066212676626,"item_id":37802231},{"lat":37.529408792365814,"lng":126.90665091796724,"item_id":37807450},{"lat":37.529771865960065,"lng":126.90746798091303,"item_id":37573837},{"lat":37.53057623456821,"lng":126.9075821373545,"item_id":37806009},{"lat":37.53076165343578,"lng":126.90697577373567,"item_id":37756478},{"lat":37.53075923013438,"lng":126.90697875250937,"item_id":37756629},{"lat":37.531384864464094,"lng":126.90690275848631,"item_id":37687435},{"lat":37.5314078370735,"lng":126.90751176536529,"item_id":37732891},{"lat":37.53173302192373,"lng":126.90512976538805,"item_id":37545432},{"lat":37.53175304885024,"lng":126.90513032665551,"item_id":37733547},{"lat":37.53175482940542,"lng":126.90513160423387,"item_id":37777449},{"lat":37.5317624665985,"lng":126.9050803412707,"item_id":37815927},{"lat":37.53176829414362,"lng":126.90513305973498,"item_id":37840494},{"lat":37.53176005897022,"lng":126.89782072410547,"item_id":37805662},{"lat":37.532436046031115,"lng":126.90507008872616,"item_id":37738304},{"lat":37.53196141066512,"lng":126.90443402287887,"item_id":37809180},{"lat":37.53249670291066,"lng":126.89673259689874,"item_id":37725362},{"lat":37.53251960021334,"lng":126.89672848065524,"item_id":37725378},{"lat":37.53203508903641,"lng":126.90595150332024,"item_id":37791522},{"lat":37.532032667285094,"lng":126.90598834478627,"item_id":37819640},{"lat":37.53255312229915,"lng":126.90533076512999,"item_id":37823879},{"lat":37.53211865281879,"lng":126.89969086774937,"item_id":37769944},{"lat":37.53210291958663,"lng":126.89969017721934,"item_id":37784321},{"lat":37.53258343197453,"lng":126.90032364570702,"item_id":37811134},{"lat":37.532114287691655,"lng":126.9003422006363,"item_id":37820390},{"lat":37.532304092426834,"lng":126.90483323526223,"item_id":37803194},{"lat":37.5330916039933,"lng":126.8956154646142,"item_id":37708036},{"lat":37.533067222733486,"lng":126.89622752621514,"item_id":37820398},{"lat":37.53308546690346,"lng":126.89219175379931,"item_id":37807105},{"lat":37.53319033893431,"lng":126.89163153910887,"item_id":37680236},{"lat":37.533178553829224,"lng":126.89160783767011,"item_id":37682630},{"lat":37.53273607261976,"lng":126.90558526406602,"item_id":37563947},{"lat":37.53326890648655,"lng":126.89165555186815,"item_id":37603729},{"lat":37.532939300346754,"lng":126.90517060988668,"item_id":37629225},{"lat":37.53297313218489,"lng":126.90560915502036,"item_id":37699830},{"lat":37.53313141089226,"lng":126.90496028845524,"item_id":37609079},{"lat":37.533629692301965,"lng":126.904982912162,"item_id":37623279},{"lat":37.53311365758317,"lng":126.90434562850123," ...

# %%
items = response.json()['items']
ids = [item['item_id'] for item in items]
len(ids), ids[:5]
# Out:
# (582, [37623131, 37685329, 37699264, 37828417, 37595863])

# %% [markdown]
# #### 4. 매물 아이디로 매물 정보 가져오기

# %%
url = f'https://apis.zigbang.com/v2/items/list'
params = {
    'domain' : 'zigbang',
    'item_ids' : ids}
response = requests.post(url, params)
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'items': [{'item_id': 37623131,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37623131/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 50,
#    'size_m2': 19.83,
#    '공급면적': {'m2': 19.83, 'p': '6'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '9',
#    'title': '당산동에서 이보다 좋은 매물 못찾습니다',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.529089114452574, 'lng': 126.89977306882251},
#    'manage_cost': '7',
#    'reg_date': '2023-08-11T12:23:15+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37685329,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37685329/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 12000,
#    'rent': 0,
#    'size_m2': 26.45,
#    '공급면적': {'m2': 26.45, 'p': '8'},
#    '전용면적': {'m2': 26.45, 'p': '8'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '7',
#    'floor_string': '7',
#    'building_floor': '9',
#    'title': '당산,구청역2,5.9호선도보5분편리한대중교통',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.529570940904904, 'lng': 126.90041396961391},
#    'manage_cost': '10',
#    'reg_date': '2023-08-14T11:20:49+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37699264,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37699264/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 50,
#    'size_m2': 19.83,
#    '공급면적': {'m2': 19.83, 'p': '6'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '9',
#    'title': '당산동에서 이보다 좋은 매물 못찾습니다',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.529084701333694, 'lng': 126.90044561904271},
#    'manage_cost': '7',
#    'reg_date': '2023-08-15T01:28:31+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37828417,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37828417/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 21900,
#    'rent': 0,
#    'size_m2': 35.58,
#    '공급면적': {'m2': 35.58, 'p': '10.8'},
#    '전용면적': {'m2': 28.42, 'p': '8.6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '6',
#    'title': '2,5,9역세권 투룸 끝판왕o',
#    'is_first_movein': None,
#    'room_type': '04',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.52908170869493, 'lng': 126.89892479898162},
#    'manage_cost': '6',
#    'reg_date': '2023-08-23T15:08:10+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37595863,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37595863/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 5000,
#    'rent': 30,
#    'size_m2': 18,
#    '공급면적': {'m2': 18, 'p': '5.4'},
#    '전용면적': {'m2': 18, 'p': '5.4'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '7',
#    'title': '오피스텔형 원룸 전세 영등포구청역 도보5분',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.52911238633145, 'lng': 126.89697340480382},
#    'manage_cost': '13',
#    'reg_date': '2023-08-02T15:38:21+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37812771,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37812771/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 40,
#    'size_m2': 13.22,
#    '공급면적': {'m2': 13.22, 'p': '4'},
#    '전용면적': {'m2': 13.22, 'p': '4'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '8',
#    'title': '최고저렴한 햇살짱짱 양창방',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.52960349181754, 'lng': 126.89699486258424},
#    'manage_cost': '13',
#    'reg_date': '2023-08-22T12:28:34+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37594373,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37594373/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 9000,
#    'rent': 0,
#    'size_m2': 19.83,
#    '공급면적': {'m2': 19.83, 'p': '6'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '7',
#    'floor_string': '7',
#    'building_floor': '7',
#    'title': '월세가능.넓은방.역세권.가성비최고',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.52921284150089, 'lng': 126.907307353759},
#    'manage_cost': '9',
#    'reg_date': '2023-08-18T13:51:28+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37779193,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37779193/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 28700,
#    'rent': 0,
#    'size_m2': 39.06,
#    '공급면적': {'m2': 39.06, 'p': '11.8'},
#    '전용면적': {'m2': 29.93, 'p': '9.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '6',
#    'title': '보증보험, 2,9호선 당산역, 채광좋고 넓은 쓰리룸',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.52928372347317, 'lng': 126.89949329950045},
#    'manage_cost': '6',
#    'reg_date': '2023-08-18T18:54:41+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37681821,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37681821/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 500,
#    'rent': 45,
#    'size_m2': 21.49,
#    '공급면적': {'m2': 21.49, 'p': '6.5'},
#    '전용면적': {'m2': 21.49, 'p': '6.5'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '4',
#    'title': '구청역 화이트톤 깔끔한방 소개해드립니다',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.52930447359159, 'lng': 126.8973472463861},
#    'manage_cost': '5',
#    'reg_date': '2023-08-22T10:40:55+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37789981,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37789981/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 500,
#    'rent': 45,
#    'size_m2': 23.14,
#    '공급면적': {'m2': 23.14, 'p': '7'},
#    '전용면적': {'m2': 23.14, 'p': '7'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '4',
#    'title': '영등포구청역 코앞  화이트톤  넓은 분리형',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.529294570368414, 'lng': 126.89735095693864},
#    'manage_cost': '5',
#    'reg_date': '2023-08-20T18:53:34+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37812120,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37812120/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 500,
#    'rent': 40,
#    'size_m2': 21.49,
#    '공급면적': {'m2': 21.49, 'p': '6.5'},
#    '전용면적': {'m2': 21.49, 'p': '6.5'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '5',
#    'title': '영등포구청역역세권.오픈형.보증금조정가능.큰방',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.529310737251954, 'lng': 126.89735265320247},
#    'manage_cost': '5',
#    'reg_date': '2023-08-22T17:12:39+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동4가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동4가',
#     'localText': '영등포구 당산동4가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동4가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동4가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37591840,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37591840/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 200,
#    'rent': 110,
#    'size_m2': 36.36,
#    '공급면적': {'m2': 36.36, 'p': '11'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '14',
#    'floor_string': '14',
#    'building_floor': '15',
#    'title': '빠른입주단기방',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.529404805715174, 'lng': 126.90752865599488},
#    'manage_cost': '8',
#    'reg_date': '2023-08-02T12:12:00+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '단기',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37647361,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37647361/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 85,
#    'size_m2': 39.23,
#    '공급면적': {'m2': 39.23, 'p': '11.9'},
#    '전용면적': {'m2': 20.23, 'p': '6.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '15',
#    'title': '사업자라면 프리미엄 오피스텔',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52938609105995, 'lng': 126.9075471775879},
#    'manage_cost': '9',
#    'reg_date': '2023-08-07T14:17:23+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37776332,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37776332/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 200,
#    'rent': 110,
#    'size_m2': 39.45,
#    '공급면적': {'m2': 39.45, 'p': '11.9'},
#    '전용면적': {'m2': 20.04, 'p': '6.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '14',
#    'floor_string': '14',
#    'building_floor': '15',
#    'title': 'v풀옵션v즉시입주v역세권v기간조율가능',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.529876856295964, 'lng': 126.90693929059243},
#    'manage_cost': '8',
#    'reg_date': '2023-08-18T16:22:02+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '단기',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37821042,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37821042/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 200,
#    'rent': 110,
#    'size_m2': 39.23,
#    '공급면적': {'m2': 39.23, 'p': '11.9'},
#    '전용면적': {'m2': 20.22, 'p': '6.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '12',
#    'floor_string': '12',
#    'building_floor': '15',
#    'title': '한강이 보이는 초고층',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.5293733628116, 'lng': 126.90694018590436},
#    'manage_cost': '9',
#    'reg_date': '2023-08-22T23:03:58+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '단기',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37822875,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37822875/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 21000,
#    'rent': 0,
#    'size_m2': 39.23,
#    '공급면적': {'m2': 39.23, 'p': '11.9'},
#    '전용면적': {'m2': 19.93, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '15',
#    'title': '당산역 귀한전세 허그등각종대출가능 10월말입주',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.529902196419265, 'lng': 126.9069355056989},
#    'manage_cost': '11',
#    'reg_date': '2023-08-23T10:34:46+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37822954,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37822954/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 90,
#    'size_m2': 39.37,
#    '공급면적': {'m2': 39.37, 'p': '11.9'},
#    '전용면적': {'m2': 20, 'p': '6.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '5',
#    'floor_string': '5',
#    'building_floor': '15',
#    'title': '9호선 풀옵션 대로변 보안굿 사업자가능',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52990816003479, 'lng': 126.9069400534172},
#    'manage_cost': '11',
#    'reg_date': '2023-08-23T10:37:04+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37830915,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37830915/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 22000,
#    'rent': 0,
#    'size_m2': 36.36,
#    '공급면적': {'m2': 36.36, 'p': '11'},
#    '전용면적': {'m2': 20.5, 'p': '6.2'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '15',
#    'title': '마지막 전세, 청년버팀목 가능',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52938024212296, 'lng': 126.90756048597723},
#    'manage_cost': '9',
#    'reg_date': '2023-08-23T17:19:29+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37831419,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37831419/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 21700,
#    'rent': 0,
#    'size_m2': 39.23,
#    '공급면적': {'m2': 39.23, 'p': '11.9'},
#    '전용면적': {'m2': 20.23, 'p': '6.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '15',
#    'title': '청년버팀목1.8 대출전문가 은행연결까지',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52989320824436, 'lng': 126.90756975365963},
#    'manage_cost': '7',
#    'reg_date': '2023-08-23T17:47:28+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37802231,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37802231/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 3000,
#    'rent': 55,
#    'size_m2': 27.87,
#    '공급면적': {'m2': 27.87, 'p': '8.4'},
#    '전용면적': {'m2': 16.75, 'p': '5.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '8',
#    'title': '역세권 큰평수 오피스텔 보증금2000에서3000가능',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52939413445375, 'lng': 126.90662582366237},
#    'manage_cost': '8',
#    'reg_date': '2023-08-21T15:06:26+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37807450,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37807450/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 3000,
#    'rent': 55,
#    'size_m2': 27.87,
#    '공급면적': {'m2': 27.87, 'p': '8.4'},
#    '전용면적': {'m2': 16.76, 'p': '5.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '8',
#    'title': 'oO 2,9호선 역세권 오피스텔',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.52942542577593, 'lng': 126.90726016371003},
#    'manage_cost': '8',
#    'reg_date': '2023-08-22T11:42:26+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37573837,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37573837/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 9000,
#    'rent': 0,
#    'size_m2': 39.67,
#    '공급면적': {'m2': 39.67, 'p': '12'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '고',
#    'floor_string': '고',
#    'building_floor': '15',
#    'title': '당산 초실속1.5룸  여성안심귀가 대출가능 조기마감예상',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.530241506977966, 'lng': 126.90684044658865},
#    'manage_cost': '7',
#    'reg_date': '2023-08-01T10:06:37+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37806009,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37806009/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 4000,
#    'rent': 50,
#    'size_m2': 29.75,
#    '공급면적': {'m2': 29.75, 'p': '9'},
#    '전용면적': {'m2': 23.14, 'p': '7'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '14',
#    'title': '전입 확정일자 가능  여성안심귀가 빠른입주 풀옵션',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53108758226674, 'lng': 126.9076037717442},
#    'manage_cost': '10',
#    'reg_date': '2023-08-21T17:47:29+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37756478,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37756478/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 3000,
#    'rent': 130,
#    'size_m2': 33.06,
#    '공급면적': {'m2': 33.06, 'p': '10'},
#    '전용면적': {'m2': 26.45, 'p': '8'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '8',
#    'floor_string': '8',
#    'building_floor': '9',
#    'title': '구해줘 홈즈 나온집 신축 한강뷰 전입 확정일자 가능 복층',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53125238021609, 'lng': 126.90697408109256},
#    'manage_cost': '9',
#    'reg_date': '2023-08-21T17:47:39+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37756629,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37756629/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 29000,
#    'rent': 0,
#    'size_m2': 33.06,
#    '공급면적': {'m2': 33.06, 'p': '10'},
#    '전용면적': {'m2': 26.45, 'p': '8'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '8',
#    'floor_string': '8',
#    'building_floor': '9',
#    'title': '한강뷰 버팀목대출 가능함 보증보험가입가능 풀옵션 복층',
#    'is_first_movein': None,
#    'room_type': '03',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53126423682472, 'lng': 126.90757292668091},
#    'manage_cost': '9',
#    'reg_date': '2023-08-22T11:16:42+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37687435,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37687435/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 65,
#    'size_m2': 30.08,
#    '공급면적': {'m2': 30.08, 'p': '9.1'},
#    '전용면적': {'m2': 17.49, 'p': '5.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '15',
#    'title': '보증금월세조정OKㅣ당산동 대표 원룸ㅣ분리형,사이즈커요ㅣ',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53138947539736, 'lng': 126.90690357501917},
#    'manage_cost': '11',
#    'reg_date': '2023-08-17T18:26:10+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37732891,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37732891/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 2000,
#    'rent': 64,
#    'size_m2': 29.52,
#    '공급면적': {'m2': 29.52, 'p': '8.9'},
#    '전용면적': {'m2': 17.17, 'p': '5.2'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '15',
#    'title': '분리형원룸 양창 뚫린뷰 즉시입주 전입가능 최저가 무융자',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53087729805086, 'lng': 126.90752774588222},
#    'manage_cost': '10',
#    'reg_date': '2023-08-15T11:29:08+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동',
#     'localText': '영등포구 당산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37545432,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37545432/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 36000,
#    'rent': 0,
#    'size_m2': 75.93,
#    '공급면적': {'m2': 75.93, 'p': '23'},
#    '전용면적': {'m2': 39.97, 'p': '12.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '19',
#    'title': '드레스룸구조 10월말 입주 가능한 오피스텔',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.531270595937144, 'lng': 126.90508176084053},
#    'manage_cost': '11',
#    'reg_date': '2023-08-11T15:37:50+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '영등포동8가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 영등포동8가',
#     'localText': '영등포구 영등포동8가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 영등포동8가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 영등포동8가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37733547,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37733547/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 39000,
#    'rent': 0,
#    'size_m2': 75.95,
#    '공급면적': {'m2': 75.95, 'p': '23'},
#    '전용면적': {'m2': 39.98, 'p': '12.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '19',
#    'floor_string': '19',
#    'building_floor': '19',
#    'title': '한강조망  방1거실 드레스룸 넓은 오피스텔',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53176605590466, 'lng': 126.90508091952749},
#    'manage_cost': '15',
#    'reg_date': '2023-08-23T13:47:57+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '영등포동8가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 영등포동8가',
#     'localText': '영등포구 영등포동8가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 영등포동8가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 영등포동8가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37777449,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37777449/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 20000,
#    'rent': 100,
#    'size_m2': 75.95,
#    '공급면적': {'m2': 75.95, 'p': '23'},
#    '전용면적': {'m2': 39.98, 'p': '12.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '7',
#    'floor_string': '7',
#    'building_floor': '19',
#    'title': '방1 거실 드레룸 바로입주가능',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53123837810856, 'lng': 126.9057241180526},
#    'manage_cost': '15',
#    'reg_date': '2023-08-18T17:15:17+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '영등포동8가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 영등포동8가',
#     'localText': '영등포구 영등포동8가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 영등포동8가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 영등포동8가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37815927,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37815927/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 3000,
#    'rent': 125,
#    'size_m2': 75.93,
#    '공급면적': {'m2': 75.93, 'p': '23'},
#    '전용면적': {'m2': 39.97, 'p': '12.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '9',
#    'floor_string': '9',
#    'building_floor': '19',
#    'title': '드레스룸 있는구조, 전입신고, 확정일자 가능',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53127074476423, 'lng': 126.90510887169644},
#    'manage_cost': '11',
#    'reg_date': '2023-08-24T11:04:06+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '영등포동8가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 영등포동8가',
#     'localText': '영등포구 영등포동8가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 영등포동8가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 영등포동8가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37840494,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37840494/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 35000,
#    'rent': 30,
#    'size_m2': 49.59,
#    '공급면적': {'m2': 49.59, 'p': '15'},
#    '전용면적': {'m2': 39.67, 'p': '12'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '19',
#    'floor_string': '19',
#    'building_floor': '19',
#    'title': 'KB시세 하한가 90이하  보증보험가입됨 전세대출가능',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.531756727675095, 'lng': 126.90510158533175},
#    'manage_cost': '11',
#    'reg_date': '2023-08-24T15:09:00+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '영등포동8가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 영등포동8가',
#     'localText': '영등포구 영등포동8가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 영등포동8가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 영등포동8가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37805662,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37805662/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 22000,
#    'rent': 0,
#    'size_m2': 30.08,
#    '공급면적': {'m2': 30.08, 'p': '9.1'},
#    '전용면적': {'m2': 30.08, 'p': '9.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '9',
#    'floor_string': '9',
#    'building_floor': '10',
#    'title': '당산 역세권 1.5룸전세자금대출 가능',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': [],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.53227444253669, 'lng': 126.89782245545823},
#    'manage_cost': '12',
#    'reg_date': '2023-08-21T17:29:30+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동5가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동5가',
#     'localText': '영등포구 당산동5가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동5가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동5가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37738304,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37738304/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 90,
#    'size_m2': 30.31,
#    '공급면적': {'m2': 30.31, 'p': '9.2'},
#    '전용면적': {'m2': 16.78, 'p': '5.1'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '15',
#    'title': '사업자가능 당산역 도보2분  초역세권 깔끔 풀옵션 복층',
#    'is_first_movein': None,
#    'room_type': '03',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.5324291978953, 'lng': 126.90443092116666},
#    'manage_cost': '13',
#    'reg_date': '2023-08-15T16:56:06+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동5가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동5가',
#     'localText': '영등포구 당산동5가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동5가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동5가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37809180,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37809180/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 90,
#    'size_m2': 32,
#    '공급면적': {'m2': 32, 'p': '9.7'},
#    '전용면적': {'m2': 17.59, 'p': '5.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '6',
#    'floor_string': '6',
#    'building_floor': '15',
#    'title': '신축, 남향, 역세권 복층오피스텔',
#    'is_first_movein': None,
#    'room_type': '03',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.53246017814854, 'lng': 126.90504806432465},
#    'manage_cost': '8',
#    'reg_date': '2023-08-24T11:27:46+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '영등포구',
#     'local3': '당산동5가',
#     'local4': '',
#     'fullText': '서울특별시 영등포구 당산동5가',
#     'localText': '영등포구 당산동5가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동5가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동5가',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37725362,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37725362/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 1000,
#    'rent': 47,
#    'size_m2': 19.83,
#    '공급면적': {'m2': 19.83, 'p': '6'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '8',
#    'floor_string': '8',
#    'building_floor': '8',
#    'title': '화이트톤 대로변 전망굿',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.532021541208806, 'lng': 126.89668448098708},
#    'manage_cost': '13',
#    'reg_date': '2023-08-24T10:02:10+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '영등포구',
#     'local3': '당산동5가',
#     'local4': '',
#     'fullText': '서울시 영등포구 당산동5가',
#     'localText': '영등포구 당산동5가'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '영등포구 당산동5가',
#    'is_zzim': False,
#    'address1': '서울시 영등포구 당산동5가',
#    'address2': None,
#    'address3': None,
# ...
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37718709,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37718709/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 32800,
#    'rent': 0,
#    'size_m2': 79.21,
#    '공급면적': {'m2': 79.21, 'p': '24'},
#    '전용면적': {'m2': 76.03, 'p': '23'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '6',
#    'title': '신혼부부버팀목가능, 마포구저렴한쓰리룸전세, 18년식 깔끔',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': [],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56642166198404, 'lng': 126.90743085437761},
#    'manage_cost': '6',
#    'reg_date': '2023-08-14T11:02:23+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37794552,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37794552/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 15000,
#    'rent': 0,
#    'size_m2': 33.06,
#    '공급면적': {'m2': 33.06, 'p': '10'},
#    '전용면적': {'m2': 33.06, 'p': '10'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '3',
#    'title': '복층원룸전세전세자금가능오늘 나온매물',
#    'is_first_movein': None,
#    'room_type': '03',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.56724803333727, 'lng': 126.90661926539904},
#    'manage_cost': '6',
#    'reg_date': '2023-08-22T09:41:09+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37750896,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37750896/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 9000,
#    'rent': 0,
#    'size_m2': 19.83,
#    '공급면적': {'m2': 19.83, 'p': '6'},
#    '전용면적': {'m2': 19.83, 'p': '6'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '1',
#    'floor_string': '1',
#    'building_floor': '3',
#    'title': '신축급풀옵션 전용넓은 원룸오늘나온 매물',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.56777701610257, 'lng': 126.90721333719863},
#    'manage_cost': '8',
#    'reg_date': '2023-08-16T17:18:05+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37797269,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37797269/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 15500,
#    'rent': 0,
#    'size_m2': 18.97,
#    '공급면적': {'m2': 18.97, 'p': '5.7'},
#    '전용면적': {'m2': 18.97, 'p': '5.7'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '5',
#    'title': '버팀목HUG중기100ㅣ완벽원룸ㅣ신축급 엘베有ㅣ구조좋아요',
#    'is_first_movein': None,
#    'room_type': '01',
#    'status': True,
#    'tags': [],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.56818001768683, 'lng': 126.9078918962043},
#    'manage_cost': '7',
#    'reg_date': '2023-08-24T15:37:38+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37805028,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37805028/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 12000,
#    'rent': 0,
#    'size_m2': 42.98,
#    '공급면적': {'m2': 42.98, 'p': '13'},
#    '전용면적': {'m2': 39.67, 'p': '12'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '2',
#    'title': '저렴한  지상투룸 lh 가능 오늘나온매물',
#    'is_first_movein': None,
#    'room_type': '04',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.5678444371492, 'lng': 126.90637111232127},
#    'manage_cost': '1',
#    'reg_date': '2023-08-22T09:41:16+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37751115,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37751115/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 2000,
#    'rent': 90,
#    'size_m2': 37.98,
#    '공급면적': {'m2': 37.98, 'p': '11.5'},
#    '전용면적': {'m2': 31.37, 'p': '9.5'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '1',
#    'floor_string': '1',
#    'building_floor': '2',
#    'title': '올리모델링 가좌역5분 역세권 귀한 투룸ㅣ빠른입주OK',
#    'is_first_movein': None,
#    'room_type': '04',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56850494651508, 'lng': 126.91156338021422},
#    'manage_cost': '0',
#    'reg_date': '2023-08-24T14:34:14+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '중동',
#     'local4': '',
#     'fullText': '서울시 마포구 중동',
#     'localText': '마포구 중동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 중동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 중동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37609788,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37609788/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 30600,
#    'rent': 0,
#    'size_m2': 44.87,
#    '공급면적': {'m2': 44.87, 'p': '13.6'},
#    '전용면적': {'m2': 37.49, 'p': '11.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '6',
#    'title': '초역세 인기매물 쓰리룸 화2ㅣ보증보험100 HUG버팀목ㅣ',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': [],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56860377517986, 'lng': 126.91373290225336},
#    'manage_cost': '5',
#    'reg_date': '2023-08-12T11:42:46+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37642948,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37642948/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 30600,
#    'rent': 0,
#    'size_m2': 44.87,
#    '공급면적': {'m2': 44.87, 'p': '13.6'},
#    '전용면적': {'m2': 37.49, 'p': '11.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '6',
#    'title': '안심전세대출 보증보험 가좌역1분 방3화2 넓은 쓰리룸',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56860970697573, 'lng': 126.91371602047695},
#    'manage_cost': '5',
#    'reg_date': '2023-08-10T14:47:06+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37788015,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37788015/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 30600,
#    'rent': 0,
#    'size_m2': 44.87,
#    '공급면적': {'m2': 44.87, 'p': '13.6'},
#    '전용면적': {'m2': 37.49, 'p': '11.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '4',
#    'floor_string': '4',
#    'building_floor': '6',
#    'title': 'O버팀목,보증보험O쓰리룸O가좌역1분O꿀매물',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56812310488723, 'lng': 126.91373501139432},
#    'manage_cost': '5',
#    'reg_date': '2023-08-19T17:05:54+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37769062,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37769062/1.jpg',
#    'sales_type': '전세',
#    'sales_title': '전세',
#    'deposit': 14000,
#    'rent': 0,
#    'size_m2': 23.14,
#    '공급면적': {'m2': 23.14, 'p': '7'},
#    '전용면적': {'m2': 23.14, 'p': '7'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '2',
#    'floor_string': '2',
#    'building_floor': '2',
#    'title': '가좌역 인근 베란다가 있는 깔끔 분리형 원룸',
#    'is_first_movein': None,
#    'room_type': '02',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '원룸',
#    'random_location': {'lat': 37.56932442060651, 'lng': 126.90895987952607},
#    'manage_cost': '11',
#    'reg_date': '2023-08-22T14:29:22+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '성산동',
#     'local4': '',
#     'fullText': '서울시 마포구 성산동',
#     'localText': '마포구 성산동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 성산동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 성산동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37703323,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37703323/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 5000,
#    'rent': 160,
#    'size_m2': 63.97,
#    '공급면적': {'m2': 63.97, 'p': '19.4'},
#    '전용면적': {'m2': 42.52, 'p': '12.9'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '3',
#    'floor_string': '3',
#    'building_floor': '6',
#    'title': '전입o 가좌역 도보5분 살기좋은 신축쓰리룸',
#    'is_first_movein': None,
#    'room_type': '05',
#    'status': True,
#    'tags': ['추천'],
#    'service_type': '빌라',
#    'random_location': {'lat': 37.56979644679233, 'lng': 126.90920724217709},
#    'manage_cost': '8',
#    'reg_date': '2023-08-12T09:50:21+09:00',
#    'is_new': False,
#    'addressOrigin': {'local1': '서울시',
#     'local2': '마포구',
#     'local3': '중동',
#     'local4': '',
#     'fullText': '서울시 마포구 중동',
#     'localText': '마포구 중동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 중동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 중동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'},
#   {'item_id': 37836529,
#    'section_type': None,
#    'images_thumbnail': 'https://ic.zigbang.com/ic/items/37836529/1.jpg',
#    'sales_type': '월세',
#    'sales_title': '월세',
#    'deposit': 5000,
#    'rent': 160,
#    'size_m2': 61.09,
#    '공급면적': {'m2': 61.09, 'p': '18.5'},
#    '전용면적': {'m2': 40.61, 'p': '12.3'},
#    '계약면적': None,
#    'room_type_title': None,
#    'floor': '고',
#    'floor_string': '고',
#    'building_floor': '6',
#    'title': '가좌역 역세권 신축  첫입주 투룸  반전세주차O',
#    'is_first_movein': None,
#    'room_type': '04',
#    'status': True,
#    'tags': [],
#    'service_type': '오피스텔',
#    'random_location': {'lat': 37.569772365274844, 'lng': 126.9098427527068},
#    'manage_cost': '8',
#    'reg_date': '2023-08-24T11:44:39+09:00',
#    'is_new': True,
#    'addressOrigin': {'local1': '서울특별시',
#     'local2': '마포구',
#     'local3': '중동',
#     'local4': '',
#     'fullText': '서울특별시 마포구 중동',
#     'localText': '마포구 중동'},
#    'action': {'isRead': False,
#     'readAt': None,
#     'isInquired': False,
#     'inquiredAt': None,
#     'isRewarded': False,
#     'rewardedAt': None,
#     'isReported': False,
#     'reportedAt': None,
#     'isChecked': False,
#     'checkedAt': None,
#     'isZzim': False},
#    'contract': '',
#    'address': '마포구 중동',
#    'is_zzim': False,
#    'address1': '서울시 마포구 중동',
#    'address2': None,
#    'address3': None,
#    'item_bm_type': 'ZIGBANG'}]}

# %%
data = response.json()['items']
df = pd.DataFrame(data)
df.tail(2)
# Out:
#       item_id section_type                                images_thumbnail  \
# 580  37703323         None  https://ic.zigbang.com/ic/items/37703323/1.jpg
# 581  37836529         None  https://ic.zigbang.com/ic/items/37836529/1.jpg
#
#     sales_type sales_title  deposit  rent  size_m2  \
# 580         월세          월세     5000   160    63.97
# 581         월세          월세     5000   160    61.09
#
#                            공급면적                        전용면적  ... is_new  \
# 580  {'m2': 63.97, 'p': '19.4'}  {'m2': 42.52, 'p': '12.9'}  ...  False
# 581  {'m2': 61.09, 'p': '18.5'}  {'m2': 40.61, 'p': '12.3'}  ...   True
#
#                                          addressOrigin  \
# 580  {'local1': '서울시', 'local2': '마포구', 'local3': '...
# 581  {'local1': '서울특별시', 'local2': '마포구', 'local3':...
#
#                                                 action contract address  \
# 580  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
# 581  {'isRead': False, 'readAt': None, 'isInquired'...           마포구 중동
#
#     is_zzim    address1 address2  address3 item_bm_type
# 580   False  서울시 마포구 중동     None      None      ZIGBANG
# 581   False  서울시 마포구 중동     None      None      ZIGBANG
#
# [2 rows x 34 columns]

# %%
# 데이터 프레임 볼 때 '...' 안나오게 하기
pd.options.display.max_columns= 40
pd.options.display.max_rows = 60

# %%
df.columns
# Out:
# Index(['item_id', 'section_type', 'images_thumbnail', 'sales_type',
#        'sales_title', 'deposit', 'rent', 'size_m2', '공급면적', '전용면적', '계약면적',
#        'room_type_title', 'floor', 'floor_string', 'building_floor', 'title',
#        'is_first_movein', 'room_type', 'status', 'tags', 'service_type',
#        'random_location', 'manage_cost', 'reg_date', 'is_new', 'addressOrigin',
#        'action', 'contract', 'address', 'is_zzim', 'address1', 'address2',
#        'address3', 'item_bm_type'],
#       dtype='object')

# %%
columns = ['item_id','sales_type', 'deposit', 'rent', 'size_m2', 
           'floor', 'floor_string','building_floor','title',
           'service_type','manage_cost','address1']

df = df[columns]
df.tail(2)
# Out:
#       item_id sales_type  deposit  rent  size_m2 floor floor_string  \
# 580  37703323         월세     5000   160    63.97     3            3
# 581  37836529         월세     5000   160    61.09     고            고
#
#     building_floor                       title service_type manage_cost  \
# 580              6     전입o 가좌역 도보5분 살기좋은 신축쓰리룸           빌라           8
# 581              6  가좌역 역세권 신축  첫입주 투룸  반전세주차O         오피스텔           8
#
#        address1
# 580  서울시 마포구 중동
# 581  서울시 마포구 중동

# %%
# 망원동만 필터링하기
result = df[df['address1'].str.contains('망원동')].reset_index(drop=True)
result
# Out:
#      item_id sales_type  deposit  rent  size_m2 floor floor_string  \
# 0   37814767         월세     2000    45    23.14     1            1
# 1   37811154         월세     2000    45    23.14     1            1
# 2   37568534         전세    23000     0    44.29     2            2
# 3   37626743         전세    28000     0    65.37     2            2
# 4   37814752         전세    27000     0    52.09     4            4
# 5   37825096         전세    27000     0    52.89     4            4
# 6   37796306         전세    16000     0    41.21     2            2
# 7   37666663         월세     1000    75    23.14     2            2
# 8   37709901         월세     1000    70    23.14     4            4
# 9   37741462         전세    14000     0    26.45     2            2
# 10  37682675         전세    11000     0    42.98   반지하          반지하
# 11  37834753         전세    18000     0    39.67     2            2
# 12  37750012         월세    10000    40    70.19     4            4
# 13  37695117         전세    30000     0    39.67     3            3
# 14  37836908         전세    16000     0    46.74     1            1
# 15  37449155         전세    30000     0    37.18     2            2
# 16  37604771         전세    30000     0    37.18     2            2
# 17  37682470         전세    30000     0    37.18     2            2
# 18  37780028         전세    30000     0    39.87     5            5
# 19  37816347         전세    30000     0    38.00     5            5
# 20  36853331         월세     2000    60    39.67     2            2
# 21  37839735         전세    21000     0    19.54     4            4
# 22  37746588         월세     3000    80    39.67   반지하          반지하
# 23  37798655         월세     2000    40    16.53     3            3
# 24  37715342         전세    25000     0    55.00     1            1
# 25  37640205         월세      400    69    16.53     3            3
# 26  37832840         월세     1000    67    23.14     1            1
# 27  37784953         월세    20000    30    39.80     2            2
# 28  37724743         전세    19000     0    42.98     4            4
# 29  37569385         월세     2000    50    23.14   반지하          반지하
# 30  37687556         월세      500    28    13.22   반지하          반지하
# 31  37435527         월세     1000    50    16.00     2            2
# 32  37537313         월세     1000    50    16.53     2            2
# 33  37822926         월세     1000    53    39.67   반지하          반지하
# 34  37527951         월세     5000    60    15.83     3            3
# 35  37629913         월세     3000    70    16.53     3            3
# 36  37693413         전세    28000     0    45.04     4            4
# 37  37695127         전세    28000     0    45.04     4            4
# 38  37794435         전세    28000     0    45.04     4            4
# 39  37832798         월세     1000    50    23.14   반지하          반지하
# 40  37722733         전세    15000     0    41.80     2            2
# 41  37769318         전세    14000     0    40.00     2            2
# 42  37838626         월세     2000    90    39.67     1            1
# 43  37687869         월세     2000   120    23.99     2            2
# 44  37705634         월세     1000   125    23.14     2            2
# 45  37709681         전세    27700     0    23.99     2            2
# 46  37709692         전세    27700     0    23.99     2            2
# 47  37709713         월세     2000   120    23.99     2            2
# 48  37835948         월세     3000   150    34.37     4            4
# 49  37757930         월세     2000   150    46.28     3            3
# 50  37523032         월세     7000    20    16.80     2            2
# 51  37753249         월세     9000     9    18.82     1            1
# 52  37759859         전세    10000     0    19.83     1            1
# 53  37554620         전세    36400     0    62.00     5            5
# 54  37291277         월세     1000    40    16.53     2            2
# 55  37741645         전세    25000     0    44.37     2            2
# 56  37743674         월세      300    72    16.53     2            2
# 57  37804362         월세      300    72    19.83     2            2
# 58  37811722         월세     2000   110    48.00     1            1
#
#    building_floor                               title service_type  \
# 0               3      3000.40 가능 . 풀옵션 . 큰 원룸 . 1.5층           원룸
# 1               3                       리모델링원룸 빠른입주가능           원룸
# 2               2                  가성비 따듯한 감성 리모델링 투룸           빌라
# 3               5               쓰리룸 빌라전세 HUG안심대출 주차가능           빌라
# 4               5            버팀목.보증보험가능. 테라스 있는 3룸이에요           빌라
# 5               5               망원역세권 테라스가 넓은 3룸 입니다.           빌라
# 6               3                 가성비 주차 동물 버팀목 가능 투룸           빌라
# 7               4                망원동 핫플 리모델링 완료후 첫 입주           원룸
# 8               4         망원 신축 첫입주 풀옵션 리모델링 평수 채광 굳굳           원룸
# 9               4            잔여세대 1개ㅣ망원역5분ㅣ올리모델링ㅣ1.5룸           원룸
# 10              2                 망원한강공원인근 투룸 전세 LH가능           빌라
# 11              4             망원역 근처여서 위치가 좋은 2룸 입니다.           빌라
# 12              5                   넓은 쓰리룸 채광좋음 HUG가능           빌라
# 13              5                     망원동 투룸전세 한번 보세요           빌라
# 14              2                        1.5층 리모델링 투룸           빌라
# 15              6     HUG버팀목ㅣ안심전세ㅣ보증보험 OK l 신축 풀옵션 2룸           빌라
# 16              6                 망원동 버팀목 대출 가능한2룸 전세           빌라
# 17              6    허그안심 보증보험가능, 신축투룸 첫입주 풀옵션,망리단길인접           빌라
# 18              6        허그버팀목대출되는마포구최저가신축투룸.한강공원도보5분           빌라
# 19              6             신축 풀옵션 버팀목,보증보험 한강공원바로앞           빌라
# 20              3                  망리단길 근처 조용한 주택가 투룸           빌라
# 21              5          대형 테라스데크  전동어닝신축급 풀옵션 1.5룸           원룸
# 22              4                   o망원동o 수리된 쓰리룸 옵션有           빌라
# 23              5      준신축 풀옵션 원룸..주차 가능..망원역 도보 10여분           원룸
# 24              2          망원역도보 5분거리 1층 3룸 거실 욕1 융자무           빌라
# 25              3                    반려동물 주차 가능 풀옵션원룸           원룸
# 26              3                1.5층 주차100프로가능 분리형원룸           원룸
# 27              5             망원동 투룸전세 버팀목 안심 보증보험 가능           빌라
# 28              4                 동교초 근처 넒은 테라스 투룸 전세           빌라
# 29              4             주차100프로O 20년식옵션빵빵한분리형원룸           원룸
# 30              3                     인기망원역 초특가 풀옵 원룸           원룸
# 31              4                      망원역 10분 풀옵션 원룸           원룸
# 32              4                      빠른입주 가능한 원룸 월세           원룸
# 33              3                       원룸금액이지만 투룸맞아요           빌라
# 34              4           신축 원룸, 전철역도보8분, EV와CCTV설치           원룸
# 35              4                 신축 첫입주 보증금 위로 조절 가능           원룸
# 36              5     마포구청역 신축급 보증보험 버팀목가능 채광좋고 넓은 투룸           빌라
# 37              5    한강공원10분ㅣ전용넓은 쾌적한 망원투룸ㅣHUG 모든대출OK           빌라
# 38              5      HUG버팀목 모든 전세대출가능, 공시X1.26됨, 큰집           빌라
# 39              3                      주차O 넓고깔끔한분리형원룸           원룸
# 40              3                    1억대 보기 힘든 가성비 투룸           빌라
# 41              4     지상투룸 조건 맟추어드려요 풀옵션 모든대출가  LH도가능           빌라
# 42              2                마포구청역5분 가성비 최고 넓은 면적           원룸
# 43              6         ,,,,,,,마포구청역 신축 첫 입주,,,,,,,           원룸
# 44              6       V망원동 신축 첫입주 풀옵션 6호선초역세권 1.5룸V           원룸
# 45              6    마포구청역 7분ㅣ풀옵션 1.5룸ㅣHUG청년버팀목 전세대출ㅣ           원룸
# 46              6    HUG청년버팀목ㅣ전세대출OKㅣ마포구청역 7분ㅣ풀옵션 1.5           원룸
# 47              6     ㅣ마포구청역 7분ㅣ신축 풀옵션 1.5룸ㅣ즉시 입주 가능ㅣ           원룸
# 48              6                마포구청역450m안전하고컨디션좋은2룸           빌라
# 49              6  귀한2룸월세,신축첫입주\r\n인테리어 이쁜,한강,6호선,역세권           빌라
# 50              4           망원동 꿀매물vv옥상로망 실현가능v주말야간미팅           원룸
# 51              4      마포구청인근 인기 원룸 입니다. 보증보험 가입 안전물건           원룸
# 52              3                      마포구청역 복층 원룸 전세           원룸
# 53              5        마포구청역 도보3분거리 3룸 거실 욕1 엘리베이터유           빌라
# 54              6           ✔⭐망원동 저렴한 원룸✔마포구청역3분✔엘베♻⭐           원룸
# 55              5                     마포구청역도보5분.풀옵션투룸           빌라
# 56              3            마포구청역 가까운 신축급 인기 원룸ㅣ풀풀옵션           원룸
# 57              3                    신축급즉시입주깔끔원룸 주차가능           원룸
# 58              3                 리모델링후 첫입주 쓰리룸월세 풀옵션           빌라
#
#    manage_cost     address1
# 0            5  서울시 마포구 망원동
# 1            5  서울시 마포구 망원동
# 2            3  서울시 마포구 망원동
# 3            0  서울시 마포구 망원동
# 4            3  서울시 마포구 망원동
# 5            3  서울시 마포구 망원동
# 6            1  서울시 마포구 망원동
# 7            5  서울시 마포구 망원동
# 8            5  서울시 마포구 망원동
# 9            5  서울시 마포구 망원동
# 10         1.5  서울시 마포구 망원동
# 11           2  서울시 마포구 망원동
# 12          14  서울시 마포구 망원동
# 13           4  서울시 마포구 망원동
# 14           3  서울시 마포구 망원동
# 15           8  서울시 마포구 망원동
# 16           8  서울시 마포구 망원동
# 17           5  서울시 마포구 망원동
# 18           8  서울시 마포구 망원동
# 19           5  서울시 마포구 망원동
# 20           0  서울시 마포구 망원동
# 21           5  서울시 마포구 망원동
# 22           0  서울시 마포구 망원동
# 23           3  서울시 마포구 망원동
# 24           0  서울시 마포구 망원동
# 25           9  서울시 마포구 망원동
# 26           3  서울시 마포구 망원동
# 27           7  서울시 마포구 망원동
# 28           2  서울시 마포구 망원동
# 29           8  서울시 마포구 망원동
# 30           4  서울시 마포구 망원동
# 31           5  서울시 마포구 망원동
# 32           5  서울시 마포구 망원동
# 33           3  서울시 마포구 망원동
# 34           7  서울시 마포구 망원동
# 35           7  서울시 마포구 망원동
# 36           5  서울시 마포구 망원동
# 37           5  서울시 마포구 망원동
# 38           5  서울시 마포구 망원동
# 39           3  서울시 마포구 망원동
# 40           0  서울시 마포구 망원동
# 41           0  서울시 마포구 망원동
# 42           0  서울시 마포구 망원동
# 43           5  서울시 마포구 망원동
# 44           5  서울시 마포구 망원동
# 45           5  서울시 마포구 망원동
# 46           5  서울시 마포구 망원동
# 47           5  서울시 마포구 망원동
# 48           3  서울시 마포구 망원동
# 49           4  서울시 마포구 망원동
# 50           5  서울시 마포구 망원동
# 51          11  서울시 마포구 망원동
# 52         2.5  서울시 마포구 망원동
# 53           5  서울시 마포구 망원동
# 54           3  서울시 마포구 망원동
# 55           1  서울시 마포구 망원동
# 56           7  서울시 마포구 망원동
# 57           7  서울시 마포구 망원동
# 58           1  서울시 마포구 망원동

# %% [markdown]
# # 함수로 만들어서 활용해보기

# %%
import pandas as pd
import requests
import geohash2

# %%
def oneroom(addr):
    url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸'
    response = requests.get(url)
    data = response.json()['items'][0]
    lat, lng = data['lat'], data['lng']
    geohash = geohash2.encode(lat, lng, precision=5)
    
    
    url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸'
    response = requests.get(url)
    
    items = response.json()['items']
    ids = [item['item_id'] for item in items]
    url = f'https://apis.zigbang.com/v2/items/list'
    params = {
        'domain' : 'zigbang',
        'item_ids' : ids}
    response = requests.post(url, params)
    data = response.json()['items']
    df = pd.DataFrame(data)
    columns = ['item_id','sales_type', 'deposit', 'rent', 'size_m2', 
               'floor', 'floor_string','building_floor','title',
               'service_type','manage_cost','address1']

    df = df[columns]
    result = df[df['address1'].str.contains(addr)].reset_index(drop=True)
    return result

# %%
oneroom('망원동')
# Out:
#      item_id sales_type  deposit  rent  size_m2 floor floor_string  \
# 0   37814767         월세     2000    45    23.14     1            1
# 1   37811154         월세     2000    45    23.14     1            1
# 2   37568534         전세    23000     0    44.29     2            2
# 3   37626743         전세    28000     0    65.37     2            2
# 4   37814752         전세    27000     0    52.09     4            4
# 5   37825096         전세    27000     0    52.89     4            4
# 6   37796306         전세    16000     0    41.21     2            2
# 7   37666663         월세     1000    75    23.14     2            2
# 8   37709901         월세     1000    70    23.14     4            4
# 9   37741462         전세    14000     0    26.45     2            2
# 10  37682675         전세    11000     0    42.98   반지하          반지하
# 11  37834753         전세    18000     0    39.67     2            2
# 12  37750012         월세    10000    40    70.19     4            4
# 13  37695117         전세    30000     0    39.67     3            3
# 14  37836908         전세    16000     0    46.74     1            1
# 15  37449155         전세    30000     0    37.18     2            2
# 16  37604771         전세    30000     0    37.18     2            2
# 17  37682470         전세    30000     0    37.18     2            2
# 18  37780028         전세    30000     0    39.87     5            5
# 19  37816347         전세    30000     0    38.00     5            5
# 20  36853331         월세     2000    60    39.67     2            2
# 21  37839735         전세    21000     0    19.54     4            4
# 22  37746588         월세     3000    80    39.67   반지하          반지하
# 23  37798655         월세     2000    40    16.53     3            3
# 24  37715342         전세    25000     0    55.00     1            1
# 25  37640205         월세      400    69    16.53     3            3
# 26  37832840         월세     1000    67    23.14     1            1
# 27  37784953         월세    20000    30    39.80     2            2
# 28  37724743         전세    19000     0    42.98     4            4
# 29  37569385         월세     2000    50    23.14   반지하          반지하
# 30  37687556         월세      500    28    13.22   반지하          반지하
# 31  37435527         월세     1000    50    16.00     2            2
# 32  37537313         월세     1000    50    16.53     2            2
# 33  37822926         월세     1000    53    39.67   반지하          반지하
# 34  37527951         월세     5000    60    15.83     3            3
# 35  37629913         월세     3000    70    16.53     3            3
# 36  37693413         전세    28000     0    45.04     4            4
# 37  37695127         전세    28000     0    45.04     4            4
# 38  37794435         전세    28000     0    45.04     4            4
# 39  37832798         월세     1000    50    23.14   반지하          반지하
# 40  37722733         전세    15000     0    41.80     2            2
# 41  37769318         전세    14000     0    40.00     2            2
# 42  37838626         월세     2000    90    39.67     1            1
# 43  37687869         월세     2000   120    23.99     2            2
# 44  37705634         월세     1000   125    23.14     2            2
# 45  37709681         전세    27700     0    23.99     2            2
# 46  37709692         전세    27700     0    23.99     2            2
# 47  37709713         월세     2000   120    23.99     2            2
# 48  37835948         월세     3000   150    34.37     4            4
# 49  37757930         월세     2000   150    46.28     3            3
# 50  37523032         월세     7000    20    16.80     2            2
# 51  37753249         월세     9000     9    18.82     1            1
# 52  37759859         전세    10000     0    19.83     1            1
# 53  37554620         전세    36400     0    62.00     5            5
# 54  37291277         월세     1000    40    16.53     2            2
# 55  37741645         전세    25000     0    44.37     2            2
# 56  37743674         월세      300    72    16.53     2            2
# 57  37804362         월세      300    72    19.83     2            2
# 58  37811722         월세     2000   110    48.00     1            1
#
#    building_floor                               title service_type  \
# 0               3      3000.40 가능 . 풀옵션 . 큰 원룸 . 1.5층           원룸
# 1               3                       리모델링원룸 빠른입주가능           원룸
# 2               2                  가성비 따듯한 감성 리모델링 투룸           빌라
# 3               5               쓰리룸 빌라전세 HUG안심대출 주차가능           빌라
# 4               5            버팀목.보증보험가능. 테라스 있는 3룸이에요           빌라
# 5               5               망원역세권 테라스가 넓은 3룸 입니다.           빌라
# 6               3                 가성비 주차 동물 버팀목 가능 투룸           빌라
# 7               4                망원동 핫플 리모델링 완료후 첫 입주           원룸
# 8               4         망원 신축 첫입주 풀옵션 리모델링 평수 채광 굳굳           원룸
# 9               4            잔여세대 1개ㅣ망원역5분ㅣ올리모델링ㅣ1.5룸           원룸
# 10              2                 망원한강공원인근 투룸 전세 LH가능           빌라
# 11              4             망원역 근처여서 위치가 좋은 2룸 입니다.           빌라
# 12              5                   넓은 쓰리룸 채광좋음 HUG가능           빌라
# 13              5                     망원동 투룸전세 한번 보세요           빌라
# 14              2                        1.5층 리모델링 투룸           빌라
# 15              6     HUG버팀목ㅣ안심전세ㅣ보증보험 OK l 신축 풀옵션 2룸           빌라
# 16              6                 망원동 버팀목 대출 가능한2룸 전세           빌라
# 17              6    허그안심 보증보험가능, 신축투룸 첫입주 풀옵션,망리단길인접           빌라
# 18              6        허그버팀목대출되는마포구최저가신축투룸.한강공원도보5분           빌라
# 19              6             신축 풀옵션 버팀목,보증보험 한강공원바로앞           빌라
# 20              3                  망리단길 근처 조용한 주택가 투룸           빌라
# 21              5          대형 테라스데크  전동어닝신축급 풀옵션 1.5룸           원룸
# 22              4                   o망원동o 수리된 쓰리룸 옵션有           빌라
# 23              5      준신축 풀옵션 원룸..주차 가능..망원역 도보 10여분           원룸
# 24              2          망원역도보 5분거리 1층 3룸 거실 욕1 융자무           빌라
# 25              3                    반려동물 주차 가능 풀옵션원룸           원룸
# 26              3                1.5층 주차100프로가능 분리형원룸           원룸
# 27              5             망원동 투룸전세 버팀목 안심 보증보험 가능           빌라
# 28              4                 동교초 근처 넒은 테라스 투룸 전세           빌라
# 29              4             주차100프로O 20년식옵션빵빵한분리형원룸           원룸
# 30              3                     인기망원역 초특가 풀옵 원룸           원룸
# 31              4                      망원역 10분 풀옵션 원룸           원룸
# 32              4                      빠른입주 가능한 원룸 월세           원룸
# 33              3                       원룸금액이지만 투룸맞아요           빌라
# 34              4           신축 원룸, 전철역도보8분, EV와CCTV설치           원룸
# 35              4                 신축 첫입주 보증금 위로 조절 가능           원룸
# 36              5     마포구청역 신축급 보증보험 버팀목가능 채광좋고 넓은 투룸           빌라
# 37              5    한강공원10분ㅣ전용넓은 쾌적한 망원투룸ㅣHUG 모든대출OK           빌라
# 38              5      HUG버팀목 모든 전세대출가능, 공시X1.26됨, 큰집           빌라
# 39              3                      주차O 넓고깔끔한분리형원룸           원룸
# 40              3                    1억대 보기 힘든 가성비 투룸           빌라
# 41              4     지상투룸 조건 맟추어드려요 풀옵션 모든대출가  LH도가능           빌라
# 42              2                마포구청역5분 가성비 최고 넓은 면적           원룸
# 43              6         ,,,,,,,마포구청역 신축 첫 입주,,,,,,,           원룸
# 44              6       V망원동 신축 첫입주 풀옵션 6호선초역세권 1.5룸V           원룸
# 45              6    마포구청역 7분ㅣ풀옵션 1.5룸ㅣHUG청년버팀목 전세대출ㅣ           원룸
# 46              6    HUG청년버팀목ㅣ전세대출OKㅣ마포구청역 7분ㅣ풀옵션 1.5           원룸
# 47              6     ㅣ마포구청역 7분ㅣ신축 풀옵션 1.5룸ㅣ즉시 입주 가능ㅣ           원룸
# 48              6                마포구청역450m안전하고컨디션좋은2룸           빌라
# 49              6  귀한2룸월세,신축첫입주\r\n인테리어 이쁜,한강,6호선,역세권           빌라
# 50              4           망원동 꿀매물vv옥상로망 실현가능v주말야간미팅           원룸
# 51              4      마포구청인근 인기 원룸 입니다. 보증보험 가입 안전물건           원룸
# 52              3                      마포구청역 복층 원룸 전세           원룸
# 53              5        마포구청역 도보3분거리 3룸 거실 욕1 엘리베이터유           빌라
# 54              6           ✔⭐망원동 저렴한 원룸✔마포구청역3분✔엘베♻⭐           원룸
# 55              5                     마포구청역도보5분.풀옵션투룸           빌라
# 56              3            마포구청역 가까운 신축급 인기 원룸ㅣ풀풀옵션           원룸
# 57              3                    신축급즉시입주깔끔원룸 주차가능           원룸
# 58              3                 리모델링후 첫입주 쓰리룸월세 풀옵션           빌라
#
#    manage_cost     address1
# 0            5  서울시 마포구 망원동
# 1            5  서울시 마포구 망원동
# 2            3  서울시 마포구 망원동
# 3            0  서울시 마포구 망원동
# 4            3  서울시 마포구 망원동
# 5            3  서울시 마포구 망원동
# 6            1  서울시 마포구 망원동
# 7            5  서울시 마포구 망원동
# 8            5  서울시 마포구 망원동
# 9            5  서울시 마포구 망원동
# 10         1.5  서울시 마포구 망원동
# 11           2  서울시 마포구 망원동
# 12          14  서울시 마포구 망원동
# 13           4  서울시 마포구 망원동
# 14           3  서울시 마포구 망원동
# 15           8  서울시 마포구 망원동
# 16           8  서울시 마포구 망원동
# 17           5  서울시 마포구 망원동
# 18           8  서울시 마포구 망원동
# 19           5  서울시 마포구 망원동
# 20           0  서울시 마포구 망원동
# 21           5  서울시 마포구 망원동
# 22           0  서울시 마포구 망원동
# 23           3  서울시 마포구 망원동
# 24           0  서울시 마포구 망원동
# 25           9  서울시 마포구 망원동
# 26           3  서울시 마포구 망원동
# 27           7  서울시 마포구 망원동
# 28           2  서울시 마포구 망원동
# 29           8  서울시 마포구 망원동
# 30           4  서울시 마포구 망원동
# 31           5  서울시 마포구 망원동
# 32           5  서울시 마포구 망원동
# 33           3  서울시 마포구 망원동
# 34           7  서울시 마포구 망원동
# 35           7  서울시 마포구 망원동
# 36           5  서울시 마포구 망원동
# 37           5  서울시 마포구 망원동
# 38           5  서울시 마포구 망원동
# 39           3  서울시 마포구 망원동
# 40           0  서울시 마포구 망원동
# 41           0  서울시 마포구 망원동
# 42           0  서울시 마포구 망원동
# 43           5  서울시 마포구 망원동
# 44           5  서울시 마포구 망원동
# 45           5  서울시 마포구 망원동
# 46           5  서울시 마포구 망원동
# 47           5  서울시 마포구 망원동
# 48           3  서울시 마포구 망원동
# 49           4  서울시 마포구 망원동
# 50           5  서울시 마포구 망원동
# 51          11  서울시 마포구 망원동
# 52         2.5  서울시 마포구 망원동
# 53           5  서울시 마포구 망원동
# 54           3  서울시 마포구 망원동
# 55           1  서울시 마포구 망원동
# 56           7  서울시 마포구 망원동
# 57           7  서울시 마포구 망원동
# 58           1  서울시 마포구 망원동

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? n
# Nothing done.

# %%
# 모듈 파일 만들기 : 변수, 함수, 클래스를 하나의 파일(.py)로 묶어서 코드 작성 실행 문법

# %%
# %%writefile zigbang.py
import pandas as pd
import requests
import geohash2

def oneroom(addr):
    url = f'https://apis.zigbang.com/v2/search?leaseYn=N&q={addr}&serviceType=원룸'
    response = requests.get(url)
    data = response.json()['items'][0]
    lat, lng = data['lat'], data['lng']
    geohash = geohash2.encode(lat, lng, precision=5)
    
    
    url = f'https://apis.zigbang.com/v2/items?deposit_gteq=0&domain=zigbang&geohash={geohash}&needHasNoFiltered=true&rent_gteq=0&sales_type_in=전세|월세&service_type_eq=원룸'
    response = requests.get(url)
    
    items = response.json()['items']
    ids = [item['item_id'] for item in items]
    url = f'https://apis.zigbang.com/v2/items/list'
    params = {
        'domain' : 'zigbang',
        'item_ids' : ids}
    response = requests.post(url, params)
    data = response.json()['items']
    df = pd.DataFrame(data)
    columns = ['item_id','sales_type', 'deposit', 'rent', 'size_m2', 
               'floor', 'floor_string','building_floor','title',
               'service_type','manage_cost','address1']

    df = df[columns]
    result = df[df['address1'].str.contains(addr)].reset_index(drop=True)
    return result
# Out:
# Writing zigbang.py

# %%
# %ls zigbang.py
# Out:
#  C 드라이브의 볼륨: WINDOWS
#  볼륨 일련 번호: 1CE2-C115
#
#  C:\Users\user\Desktop\Kt_Study\Study\4.WebCrawling 디렉터리
#
# 2023-08-24  오후 05:02             1,200 zigbang.py
#                1개 파일               1,200 바이트
#                0개 디렉터리  171,557,662,720 바이트 남음
