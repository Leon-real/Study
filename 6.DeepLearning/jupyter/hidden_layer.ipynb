# %% [markdown]
# # 레모네이드 판매 예측

# %%
# !pip install tensorflow

# %% [markdown]
# ## 0. 라이브러리 및 데이터 준비

# %%
import pandas as pd
import tensorflow as tf

# 데이터를 준비합니다.
path = "../data/boston.csv"
df = pd.read_csv(path)
df.head(2)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#        b  lstat  medv
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6

# %% [markdown]
# ## 1. x,y 분리

# %%
x_train = df[['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
       'ptratio', 'b', 'lstat']]
y_train = df[['medv']]
print(x_train.shape, y_train.shape)
# Out:
# (506, 13) (506, 1)

# %% [markdown]
# ## 2. 모델 준비

# %%
# 모델을 준비합니다.
X = tf.keras.Input(shape=[13])
H = tf.keras.layers.Dense(16, activation='swish')(X)
H = tf.keras.layers.Dense(16, activation='swish')(H)
Y = tf.keras.layers.Dense(1)(H)

model = tf.keras.Model(X, Y)
model.compile(loss='mse')
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 13)]              0
#
#  dense (Dense)               (None, 16)                224
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 513 (2.00 KB)
# Trainable params: 513 (2.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. 모델 학습하기

# %%
# 모델 학습
model.fit(x_train, y_train, epochs=1000, verbose=0)
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 2ms/step - loss: 15.1797
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.0502
# Epoch 3/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.8496
# Epoch 4/10
# 16/16 [==============================] - 0s 2ms/step - loss: 13.7796
# Epoch 5/10
# 16/16 [==============================] - 0s 2ms/step - loss: 12.6188
# Epoch 6/10
# 16/16 [==============================] - 0s 2ms/step - loss: 14.1874
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.8631
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 11.2388
# Epoch 9/10
# 16/16 [==============================] - 0s 2ms/step - loss: 11.7526
# Epoch 10/10
# 16/16 [==============================] - 0s 2ms/step - loss: 14.7934

# %% [markdown]
# ## 4. 모델 이용하기

# %%
# 모델을 이용합니다.
y_pred = model.predict(x_train[0:5])
print(y_pred)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# [[24.498285]
#  [19.756582]
#  [26.798023]
#  [30.007849]
#  [27.06631 ]]

# %%
model.get_weights()
# Out:
# [array([[ 3.18969816e-01, -4.06533241e-01, -3.45992953e-01,
#           4.29019570e-01, -1.02922931e-01, -4.18493450e-02,
#           5.23700178e-01,  1.40580721e-02,  3.34420130e-02,
#           5.02602160e-01,  1.37279212e-01,  6.62882626e-01,
#           1.27767205e-01,  1.76771674e-02,  3.83329630e-01,
#          -7.94783235e-01],
#         [ 2.11799089e-02,  1.46958485e-01, -1.82498619e-02,
#           3.63028288e-01, -5.93259372e-02, -5.61099872e-02,
#          -2.55475342e-01,  3.59972209e-01,  2.25536674e-01,
#          -2.89794859e-02, -3.72417569e-01,  2.49034911e-01,
#          -3.33678007e-01, -3.71144852e-03, -3.82722706e-01,
#          -5.91031611e-02],
#         [ 3.38749468e-01, -4.49372262e-01,  2.88412571e-01,
#           2.82128274e-01, -3.98267925e-01,  5.91267288e-01,
#           1.07280686e-01],
#         [-1.60994723e-01,  1.02339044e-01,  1.92287743e-01,
#          -9.16175842e-02, -1.47503868e-01, -5.50848395e-02,
#           2.29192927e-01, -3.91244143e-01,  2.90827483e-01,
#          -7.78083727e-02, -2.36861035e-01, -3.17564467e-03,
#           4.00981456e-01, -1.73345879e-01,  3.96791458e-01,
#           1.69018328e-01],
#         [ 4.25150633e-01,  1.42058229e+00, -2.61016190e-01,
#           7.14877844e-02, -1.14135015e+00, -1.23817360e+00,
#          -1.31791210e+00,  5.65095544e-01, -4.05048043e-01,
#          -1.73797563e-01,  1.04137003e-01,  3.04066986e-01,
#          -4.41716254e-01, -8.97551656e-01,  4.13618088e-02,
#           2.66860962e-01]], dtype=float32),
#  array([-2.44801849e-01, -2.59920686e-01,  3.97551447e-01,  9.26314238e-24,
#          1.10927612e-01, -1.24361195e-01,  1.61918536e-01, -4.71184462e-01,
#          1.77827314e-01,  1.88735157e-01,  6.23036624e-24, -3.80158216e-01,
#          1.99119300e-01,  4.09744054e-01, -2.86746383e-01, -2.14469671e-01],
#        dtype=float32),
#  array([[-0.25812876, -0.19567338,  0.28357756,  0.04596759, -0.23681515,
#          -0.13500136,  0.07919595, -0.01158777, -0.6680322 , -0.28557625,
#           0.4583991 ,  0.10907083,  0.17346099, -0.24338877, -0.2551725 ,
#          -0.13490595],
#         [-0.09358474, -0.19841425,  0.19436653, -0.4181059 ,  0.02771417,
#          -0.11072116,  0.46359172,  0.06996894,  0.12345186, -0.05529427,
#          -0.14542228,  0.14560169,  0.15198168, -0.2670108 , -0.40706024,
#          -0.2895128 ],
#         [ 0.35376382, -0.39394495, -0.04775161, -0.11935293, -0.13486959,
#           0.19815844,  0.04356307, -0.16697314, -0.4202995 ,  0.36164764,
#           0.04421092,  0.15881394,  0.12653898, -0.36724836, -0.16700327,
#           0.0762703 ],
#         [ 0.20902756,  0.13217905, -0.12022305, -0.08554974, -0.39538977,
#           0.05492917,  0.09408405,  0.24463186, -0.12177533, -0.40756208,
#          -0.028514  ,  0.26300278, -0.19559595,  0.21681246,  0.19299713,
#           0.1748083 ],
#         [ 0.71724457,  0.24062464, -0.02070883,  0.01552099, -0.41494128,
#           0.05615181, -0.23977701, -0.39926153, -0.12639524,  0.09641053,
#          -0.03139307,  0.03118172, -0.2645405 ,  0.19651529, -0.09331089,
#           0.3015746 ],
#         [ 0.3160059 , -0.34427464, -0.55520797, -0.16180737, -0.25091398,
#           0.22436185, -0.34458062, -0.25739396,  0.02581806, -0.02754447,
#          -0.23507588,  0.27018577, -0.384803  ,  0.3859569 , -0.17601886,
#           0.04705786],
#         [ 0.18241024, -0.4178724 , -0.157454  , -0.12686384, -0.7650591 ,
#          -0.2231329 , -0.4916322 , -0.29626122,  0.24130356, -0.5040009 ,
#           0.33430797, -0.5951128 ,  0.14804122, -0.25322604,  0.2821181 ,
#          -0.08268358],
#         [-0.41635418,  0.2690306 ,  0.30030292, -0.01692655,  0.21618918,
#          -0.42272997, -0.41065025,  0.17418595, -0.24880025, -0.1878457 ,
#           0.13286732,  0.05953687,  0.03468923, -0.4017886 ,  0.4061142 ,
#           0.08440592],
#         [ 0.29897833,  0.41734388, -0.37643036,  0.10896111, -0.04036813,
#          -0.32647756, -0.14939314, -0.3498072 ,  0.3401593 , -0.11477036,
#           0.44161922, -0.03741593, -0.45612028, -0.21488076,  0.25523815,
#           0.38349304],
#         [-0.08126418,  0.00216532,  0.23344967,  0.3259192 ,  0.22200091,
#          -0.18311131, -0.3239398 , -0.16917294,  1.04748   ,  0.1808903 ,
#           0.12861496, -0.33384493,  0.21074289,  0.19933966,  0.3076003 ,
#           0.46854207],
#         [ 0.17733029, -0.3238854 , -0.17283368, -0.3728958 ,  0.08457735,
#           0.39807943, -0.02763328,  0.20470342,  0.42861298,  0.32287386,
#          -0.38802415,  0.20221415,  0.03210163,  0.33544984, -0.42874235,
#          -0.41505843],
#         [ 0.03647251, -0.22919175,  0.10830419,  0.02734078,  0.18918465,
#          -0.43919167, -0.3198199 ,  0.05814951, -0.1914341 , -0.07729097,
#           0.08819224,  0.28737834, -0.35364485, -0.4056148 , -0.20157427,
#           0.05203477],
#         [ 0.2654939 ,  0.08122972, -0.04080511, -0.08777089,  0.3701704 ,
#           0.12047141, -0.18742484,  0.04404619,  0.34260798,  0.12718588,
#          -0.10389344,  0.12207737, -0.03854504,  0.12941858, -0.36496133,
#          -0.15305774],
#         [ 0.64806414, -0.07188264, -0.45375907,  0.40640152, -1.2616858 ,
#          -0.03463727,  0.5494707 , -0.03860927, -0.84516925,  0.21561731,
#           0.40367055, -0.46719646, -0.13248095, -0.39799303, -0.03495803,
#          -0.32064876],
#         [-0.22236581, -0.2649762 , -0.9603575 ,  0.22637084, -0.29908973,
#           0.2489759 ,  0.30272388, -0.21967742, -0.3675892 , -0.38505888,
#          -0.34490263,  0.12834094,  0.0158675 , -0.06594664, -0.19050837,
#          -0.30534697],
#         [-0.3876897 ,  0.00455302,  0.05104657, -0.18050367, -0.39196748,
#          -0.19416448,  0.08212888,  0.3047442 , -0.52345026, -0.26373166,
#          -0.67402697,  0.38604754, -0.09452394,  0.22333017, -0.10873881,
#           0.3527702 ]], dtype=float32),
#  array([ 3.4240216e-01, -8.6485350e-14,  1.5907501e-01, -4.4482214e-05,
#         -4.4080645e-01, -1.9003349e-04,  2.8466064e-01, -3.7428743e-10,
#          1.1087377e-01,  4.8141191e-03,  3.7616485e-01, -3.5927731e-01,
#         -2.3115252e-04,  0.0000000e+00,  0.0000000e+00, -2.8036140e-02],
#        dtype=float32),
#  array([[ 0.53384566],
#         [-0.1979092 ],
#         [ 0.28704026],
#         [-0.39382043],
#         [-0.10811131],
#         [ 0.45989987],
#         [ 0.46273324],
#         [ 0.25529706],
#         [ 0.80648774],
#         [-1.2659743 ],
#         [ 0.09254666],
#         [-0.33657423],
#         [ 0.2785925 ],
#         [ 0.15408397],
#         [ 0.5013089 ],
#         [-1.3301003 ]], dtype=float32),
#  array([0.34209582], dtype=float32)]
