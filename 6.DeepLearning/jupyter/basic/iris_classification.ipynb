# %% [markdown]
# # 아이리스 품종 예측

# %%
# !pip install tensorflow

# %% [markdown]
# ## 0. 라이브러리 및 데이터 준비

# %%
import pandas as pd
import tensorflow as tf

# 데이터를 준비합니다.
path = "../../data/iris.csv"
df = pd.read_csv(path)
df.head(2)
# Out:
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭      품종
# 0   5.1  3.5    1.4   0.2  setosa
# 1   4.9  3.0    1.4   0.2  setosa

# %%
df_onehot = pd.get_dummies(df)
print(df_onehot.columns)
df_onehot.head(2)
# Out:
# Index(['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭', '품종_setosa', '품종_versicolor',
#        '품종_virginica'],
#       dtype='object')
#    꽃잎길이  꽃잎폭  꽃받침길이  꽃받침폭  품종_setosa  품종_versicolor  품종_virginica
# 0   5.1  3.5    1.4   0.2          1              0             0
# 1   4.9  3.0    1.4   0.2          1              0             0

# %% [markdown]
# ## 1. x,y 분리

# %%
x_train = df_onehot[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
y_train = df_onehot[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(x_train.shape, y_train.shape)
# Out:
# (150, 4) (150, 3)

# %% [markdown]
# ## 2. 모델 준비

# %%
# 모델을 완성합니다
X = tf.keras.Input(shape=[4])
H = tf.keras.layers.Dense(64, activation='swish')(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Dense(64, activation='swish')(H)
Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.Model(X, Y)
model.compile(loss="categorical_crossentropy", metrics="accuracy")
# activation이 sigmoid일 때는 loss는 binary_crossentropy
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 4)]               0
#
#  dense_9 (Dense)             (None, 64)                320
#
#  batch_normalization (Batch  (None, 64)                256
#  Normalization)
#
#  dense_10 (Dense)            (None, 64)                4160
#
#  dense_11 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 4931 (19.26 KB)
# Trainable params: 4803 (18.76 KB)
# Non-trainable params: 128 (512.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 3. 모델 학습하기

# %%
# 모델을 학습합니다.
model.fit(x_train, y_train, epochs=500, verbose=0)
model.fit(x_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0117 - accuracy: 0.9933
# Epoch 2/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9867
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 0.9933
# Epoch 4/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 0.9800
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0673 - accuracy: 0.9733
# Epoch 6/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 7/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 8/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 9/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9933
# Epoch 10/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9867

# %% [markdown]
# ## 4. 모델 이용하기

# %%
# 모델을 이용합니다.
model.predict(x_train[-5:])
# Out:
# 1/1 [==============================] - 0s 26ms/step
# array([[4.8971421e-11, 3.4438842e-13, 1.0000000e+00],
#        [1.0091605e-08, 1.4314905e-09, 1.0000000e+00],
#        [3.9675709e-07, 5.9974047e-07, 9.9999905e-01],
#        [8.3053244e-09, 6.0081518e-08, 9.9999988e-01],
#        [3.0271804e-05, 2.8722500e-02, 9.7124726e-01]], dtype=float32)

# %%
y_train[-5:]
# Out:
#      품종_setosa  품종_versicolor  품종_virginica
# 145          0              0             1
# 146          0              0             1
# 147          0              0             1
# 148          0              0             1
# 149          0              0             1

# %%
#         1.4129184e-03, 1.9096302e-02, 9.2201689e-03, 1.4149423e-01,
#         1.1159139e-03, 3.1220594e-03, 3.4941506e-02, 4.4706049e-03,
#         2.6984096e-01, 3.8803744e-04, 5.1947315e-03, 5.5565327e-01,
#         1.8816802e-03, 4.8964510e-05, 7.0023290e-03, 1.0413176e-03],
#        dtype=float32),
#  array([[-0.07720468,  0.02787749,  0.10370696, ..., -0.1622696 ,
#          -0.03104433,  0.04945784],
#         [ 0.07111847,  0.24932717,  0.20474464, ...,  0.09818217,
#          -0.10434502,  0.1369328 ],
#         [-0.14368996, -0.09830553,  0.08040512, ...,  0.09782664,
#           0.2515385 , -0.2367254 ],
#         ...,
#         [-0.03316456,  0.20741561, -0.04864065, ..., -0.04764829,
#           0.05531477,  0.16644768],
#         [-0.22392698,  0.0551981 , -0.05540374, ...,  0.08143485,
#           0.00315174, -0.18744949],
#         [ 0.25305086,  0.09125843,  0.20457366, ..., -0.0660658 ,
#           0.09318486,  0.03638384]], dtype=float32),
#  array([-0.03081399, -0.027767  ,  0.02491326,  0.09474462,  0.0029491 ,
#          0.05000713,  0.03834764,  0.02008441,  0.0030961 , -0.05260887,
#          0.01329941,  0.10270065, -0.00125554,  0.07330916,  0.09966049,
#          0.06357597,  0.0208297 ,  0.09900871,  0.0597964 ,  0.01030489,
#          0.02192624,  0.00802631,  0.02175507, -0.02207855, -0.02209811,
#          0.01583203,  0.0231895 ,  0.00800086,  0.09452368, -0.0338902 ,
#          0.03307487,  0.03504226,  0.0832765 ,  0.10692123, -0.00013692,
#          0.03443076,  0.00271146,  0.06757004,  0.00807397,  0.05079173,
#          0.02123926,  0.06578162,  0.0541079 ,  0.02545631,  0.00937186,
#          0.01189602,  0.02470907,  0.12510562,  0.09593036,  0.03769742,
#          0.10814746, -0.00925094, -0.02016497,  0.02943728, -0.0093335 ,
#         -0.01712477, -0.01962955,  0.02193861,  0.00782394,  0.00993699,
#         -0.02501912,  0.03374668,  0.03557966,  0.05584431], dtype=float32),
#  array([[-0.16990393, -0.13108857,  0.37675053],
#         [ 0.07313954, -0.18662903,  0.01670102],
#         [-0.20217748, -0.5760303 ,  0.5851677 ],
#         [-0.6367099 ,  0.23227891,  0.16116703],
#         [-0.30360666, -0.22623414,  0.07455288],
#         [ 0.38393128, -0.16947505, -0.34005377],
#         [-0.3729734 ,  0.22031552,  0.17947999],
#         [ 0.6057308 ,  0.04624236,  0.0068404 ],
#         [ 0.18420991,  0.50502336, -0.49959686],
#         [-0.00350009, -0.4550693 ,  0.48053285],
#         [ 0.02258977,  0.5314884 , -0.39450642],
#         [ 0.44422284,  0.25881824, -0.47185165],
#         [ 0.0420455 , -0.03269643,  0.42823234],
#         [ 0.25052556, -0.44347233,  0.09848486],
#         [ 0.22836663, -0.18965854, -0.08780904],
#         [-0.72075474, -0.13372357, -0.14075258],
#         [-0.41602883,  0.15492834, -0.28548518],
#         [ 0.388833  , -0.2132586 , -0.17790037],
#         [-0.57169074, -0.08858851,  0.08392703],
#         [-0.13862541, -0.2808441 ,  0.2500406 ],
#         [-0.40754163,  0.23784357,  0.09816635],
#         [-0.05074194,  0.18450753, -0.20154674],
#         [-0.21552506,  0.3263433 ,  0.12132143],
#         [ 0.08702135, -0.07037598,  0.27570033],
#         [-0.06982596,  0.10214088, -0.00898132],
#         [-0.0781595 ,  0.50350887, -0.12227665],
#         [-0.36751315,  0.37129462,  0.04059148],
#         [ 0.07848359,  0.18138404,  0.21534462],
#         [ 0.13223068,  0.01936328, -0.57700914],
#         [ 0.16072118,  0.4581934 , -0.13758978],
#         [-0.5588458 ,  0.27114955,  0.09752537],
#         [-0.06774458,  0.2316243 ,  0.0075575 ],
#         [ 0.6398533 , -0.25771144, -0.3214581 ],
#         [ 0.49174652, -0.22321212,  0.05588829],
#         [-0.26025566,  0.02152419, -0.23999205],
#         [-0.21507923, -0.06438131,  0.20548801],
#         [-0.01240307,  0.48679134, -0.4068391 ],
#         [ 0.2990221 , -0.2956158 ,  0.03698941],
#         [-0.1853926 , -0.12097824,  0.29269364],
#         [ 0.45589545,  0.15885203,  0.29185706],
#         [-0.5382855 , -0.20424531,  0.03985384],
#         [ 0.41861013,  0.343669  , -0.32714492],
#         [ 0.21102823,  0.4319105 , -0.2762834 ],
#         [ 0.26570138,  0.38472813, -0.44862562],
#         [-0.19586381,  0.20291121, -0.03393713],
#         [-0.30833906,  0.29803446, -0.02189856],
#         [-0.31324044, -0.13288172,  0.3232443 ],
#         [-0.66052395,  0.24019162,  0.23793203],
#         [ 0.70259845,  0.07956411, -0.10415719],
#         [-0.39976528,  0.18090124,  0.06420641],
#         [ 0.3798606 , -0.06207633,  0.12334976],
#         [ 0.16036497,  0.24600752, -0.39065418],
#         [ 0.0507077 ,  0.12122551, -0.20581692],
#         [-0.56393135, -0.28429338, -0.10405054],
#         [-0.09158505,  0.00553248,  0.16219923],
#         [-0.22869298, -0.2412708 , -0.21164146],
#         [ 0.17126253,  0.25949118, -0.367536  ],
#         [-0.64464426,  0.2230427 , -0.06588491],
#         [ 0.5284234 , -0.16563103, -0.01338923],
#         [-0.37984863, -0.05610805,  0.21245967],
#         [ 0.03766881,  0.08246353, -0.18536954],
#         [-0.4139183 , -0.03370228,  0.14591154],
#         [ 0.06788094, -0.3238576 ,  0.00838501],
#         [-0.3890955 , -0.1303724 , -0.07059851]], dtype=float32),
#  array([-0.26014662,  0.0062147 ,  0.00954728], dtype=float32)]

# %% [markdown]
# ## 저장 및 로딩

# %%
# 모델 저장
model.save("./save_model/my_model.keras")

# %%
# 모델 로딩
my_model = tf.keras.models.load_model("./save_model/my_model.keras")

# %%
# 로딩된 모델 이용하기
my_model.predict(x_train[:5])
# Out:
# 1/1 [==============================] - 0s 81ms/step
# array([[1.0000000e+00, 2.8667499e-11, 1.8572971e-21],
#        [1.0000000e+00, 4.0418597e-09, 8.3647315e-21],
#        [1.0000000e+00, 9.9794617e-12, 3.1652124e-18],
#        [1.0000000e+00, 1.7600515e-09, 2.7857667e-18],
#        [1.0000000e+00, 3.5855516e-12, 4.8156643e-20]], dtype=float32)
