# %%
from ultralytics import YOLO
import cv2
from glob import glob
import datetime

# %% [markdown]
# # 학습된 가중치 가져오기

# %%
model = YOLO(model='./best.pt', task='detect')
model
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(16, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(48, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %% [markdown]
# # 모델로 예측하기

# %%
imgs = glob('./TEST_IMG/*')
imgs
# Out:
# ['./TEST_IMG\\10000_1.jpg',
#  './TEST_IMG\\1000_1.jpg',
#  './TEST_IMG\\50000_1.jpg',
#  './TEST_IMG\\5000_1.jpg',
#  './TEST_IMG\\500_1.jpg']

# %%
for img in imgs:
    model.predict(source=img,
                          conf=0.25,
                          iou=0.7,
                          save=True,
                          line_width=2
                          )
# Out:
# image 1/1 C:\Users\user\Desktop\KT_Study\Study\7.VisionDeepLearing\jupyter_file\project\TEST_IMG\10000_1.jpg: 640x640 (no detections), 172.2ms
# Speed: 5.0ms preprocess, 172.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\KT_Study\Study\7.VisionDeepLearing\jupyter_file\project\TEST_IMG\1000_1.jpg: 480x640 1 1000, 151.1ms
# Speed: 3.2ms preprocess, 151.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\KT_Study\Study\7.VisionDeepLearing\jupyter_file\project\TEST_IMG\50000_1.jpg: 640x480 (no detections), 143.2ms
# Speed: 2.0ms preprocess, 143.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs\detect\predict
#
# image 1/1 C:\Users\user\Desktop\KT_Study\Study\7.VisionDeepLearing\jupyter_file\project\TEST_IMG\5000_1.jpg: 640x480 1 5000, 132.1ms
# ...

# %% [markdown]
# # 실시간 예측하기

# %%
wondic = {0: '10',
          1: '50',
          2: '100',
          3: '500',
          4: '1000',
          5: '5000',
          6: '10000',
          7: '50000'}

CONFIDENCE_THRESHOLD = 0.6
GREEN = (0, 255, 0)
WHITE = (255, 255, 255)

model = YOLO(model='./best.pt', task='detect')

# cap = cv2.VideoCapture(0)
cap = cv2.VideoCapture(cv2.CAP_DSHOW+0) # 바로 위에 코드 안될시,이 코드로 진행
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

while True:
    start = datetime.datetime.now()

    ret, frame = cap.read()
#     print("읽는중")
    if not ret:
        print('Cam Error')
        break

    detection = model(frame)[0]

    for data in detection.boxes.data.tolist(): # data : [xmin, ymin, xmax, ymax, confidence_score, class_id]
        confidence = float(data[4])
        if confidence < CONFIDENCE_THRESHOLD:
            continue

        xmin, ymin, xmax, ymax = int(data[0]), int(data[1]), int(data[2]), int(data[3])
        label = int(data[5])
        cv2.rectangle(frame, (xmin, ymin), (xmax, ymax), GREEN, 2)
        cv2.putText(frame, wondic[label]+' '+str(round(confidence, 2)) + '%', (xmin, ymin), cv2.FONT_ITALIC, 1, WHITE, 2)
#         print(label)

    end = datetime.datetime.now()

    total = (end - start).total_seconds()
    print(f'Time to process 1 frame: {total * 1000:.0f} milliseconds')

    fps = f'FPS: {1 / total:.2f}'
    cv2.putText(frame, fps, (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    cv2.imshow('frame', frame)

    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       3 WHITE = (255, 255, 255)
#       5 # coco128 = open('./yolov8_pretrained/coco128.txt', 'r')
#       6 # data = coco128.read()
#       7 # class_list = data.split('\n')
#       8 # coco128.close()
# ---> 10 model = YOLO(model='./best.pt', task='detect')
#      12 # cap = cv2.VideoCapture(0)
#      13 cap = cv2.VideoCapture(cv2.CAP_DSHOW+0)
#
# NameError: name 'YOLO' is not defined
