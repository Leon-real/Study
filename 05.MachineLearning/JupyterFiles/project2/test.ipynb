# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# 회귀 모델
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

# 회귀 성능 튜닝
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# 회귀 평가
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape
from sklearn.metrics import r2_score

# 딥러닝
import tensorflow as tf

import warnings
warnings.filterwarnings(action='ignore') # pd 경고메시지 생략

# %%
# df = pd.read_csv('./data/df.csv')
df = joblib.load('./data/df.pkl')
df.head()

drop_col = '7days_waiting_time'
df = df.drop(drop_col, axis=1)

df = df.astype('float')

# %%
target = 'target'

x = df.drop(target, axis=1)
y = df.loc[:,target]

# %%
# 가변수화
dumm_cols = ['year','month','week','weekday','holiday']
x = pd.get_dummies(x, columns=dumm_cols, drop_first=True)

# %%
display(x.head(2))
display(y.head(2))
# Out:
#             car_cnt  request_cnt  ride_cnt  waiting_time    fare  distance  \
# time
# 2015-01-01    213.0       1023.0     924.0          23.2  2427.0   10764.0
# 2015-01-02    420.0       3158.0    2839.0          17.2  2216.0    8611.0
#
#             temp_max  temp_min  rain(mm)  humidity_max(%)  ...  week_51.0  \
# time                                                       ...
# 2015-01-01      -2.0      -8.9       0.0             63.0  ...          0
# 2015-01-02       2.4      -9.2       0.0             73.0  ...          0
#
#             week_52.0  week_53.0  weekday_1.0  weekday_2.0  weekday_3.0  \
# time
# 2015-01-01          0          0            0            0            1
# 2015-01-02          0          0            0            0            0
#
#             weekday_4.0  weekday_5.0  weekday_6.0  holiday_1.0
# time
# 2015-01-01            0            0            0            1
# 2015-01-02            1            0            0            0
#
# [2 rows x 89 columns]
# time
# 2015-01-01    17.2
# 2015-01-02    26.2
# Name: target, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 92, shuffle=False)

x_train.head()
# Out:
#             car_cnt  request_cnt  ride_cnt  waiting_time    fare  distance  \
# time
# 2015-01-01    213.0       1023.0     924.0          23.2  2427.0   10764.0
# 2015-01-02    420.0       3158.0    2839.0          17.2  2216.0    8611.0
# 2015-01-03    209.0       1648.0    1514.0          26.2  2377.0   10198.0
# 2015-01-04    196.0       1646.0    1526.0          24.5  2431.0   10955.0
# 2015-01-05    421.0       4250.0    3730.0          26.2  2214.0    8663.0
#
#             temp_max  temp_min  rain(mm)  humidity_max(%)  ...  week_51.0  \
# time                                                       ...
# 2015-01-01      -2.0      -8.9       0.0             63.0  ...          0
# 2015-01-02       2.4      -9.2       0.0             73.0  ...          0
# 2015-01-03       8.2       0.2       0.0             89.0  ...          0
# 2015-01-04       7.9      -0.9       0.0             95.0  ...          0
# 2015-01-05       4.1      -7.4       3.4             98.0  ...          0
#
#             week_52.0  week_53.0  weekday_1.0  weekday_2.0  weekday_3.0  \
# time
# 2015-01-01          0          0            0            0            1
# 2015-01-02          0          0            0            0            0
# 2015-01-03          0          0            0            0            0
# 2015-01-04          0          0            0            0            0
# 2015-01-05          0          0            0            0            0
#
#             weekday_4.0  weekday_5.0  weekday_6.0  holiday_1.0
# time
# 2015-01-01            0            0            0            1
# 2015-01-02            1            0            0            0
# 2015-01-03            0            1            0            1
# 2015-01-04            0            0            1            1
# 2015-01-05            0            0            0            0
#
# [5 rows x 89 columns]

# %%
# x_train, x_test, y_train, y_test = train_test_split(x.iloc[:,5:11],y, test_size= 92, shuffle=False)

# %%
x_train
# Out:
#             car_cnt  request_cnt  ride_cnt  waiting_time    fare  distance  \
# time
# 2015-01-01    213.0       1023.0     924.0          23.2  2427.0   10764.0
# 2015-01-02    420.0       3158.0    2839.0          17.2  2216.0    8611.0
# 2015-01-03    209.0       1648.0    1514.0          26.2  2377.0   10198.0
# 2015-01-04    196.0       1646.0    1526.0          24.5  2431.0   10955.0
# 2015-01-05    421.0       4250.0    3730.0          26.2  2214.0    8663.0
# ...             ...          ...       ...           ...     ...       ...
# 2022-09-26    642.0       5947.0    5039.0          45.5  2236.0    8529.0
# 2022-09-27    667.0       6044.0    5087.0          43.6  2238.0    8585.0
# 2022-09-28    670.0       6182.0    5176.0          44.7  2258.0    8751.0
# 2022-09-29    655.0       5981.0    5008.0          42.9  2242.0    8568.0
# 2022-09-30    658.0       5808.0    4836.0          45.7  2248.0    8636.0
#
#             temp_max  temp_min  rain(mm)  humidity_max(%)  ...  week_51.0  \
# time                                                       ...
# 2015-01-01      -2.0      -8.9       0.0             63.0  ...          0
# 2015-01-02       2.4      -9.2       0.0             73.0  ...          0
# 2015-01-03       8.2       0.2       0.0             89.0  ...          0
# 2015-01-04       7.9      -0.9       0.0             95.0  ...          0
# 2015-01-05       4.1      -7.4       3.4             98.0  ...          0
# ...              ...       ...       ...              ...  ...        ...
# 2022-09-26      27.7      14.1       0.0             86.0  ...          0
# 2022-09-27      25.8      16.3       0.0             84.0  ...          0
# 2022-09-28      26.3      16.5       0.0             92.0  ...          0
# 2022-09-29      27.7      14.9       0.0             89.0  ...          0
# 2022-09-30      27.5      14.4       0.0             88.0  ...          0
#
#             week_52.0  week_53.0  weekday_1.0  weekday_2.0  weekday_3.0  \
# time
# 2015-01-01          0          0            0            0            1
# 2015-01-02          0          0            0            0            0
# 2015-01-03          0          0            0            0            0
# 2015-01-04          0          0            0            0            0
# 2015-01-05          0          0            0            0            0
# ...               ...        ...          ...          ...          ...
# 2022-09-26          0          0            0            0            0
# 2022-09-27          0          0            1            0            0
# 2022-09-28          0          0            0            1            0
# 2022-09-29          0          0            0            0            1
# 2022-09-30          0          0            0            0            0
#
#             weekday_4.0  weekday_5.0  weekday_6.0  holiday_1.0
# time
# 2015-01-01            0            0            0            1
# 2015-01-02            1            0            0            0
# 2015-01-03            0            1            0            1
# 2015-01-04            0            0            1            1
# 2015-01-05            0            0            0            0
# ...                 ...          ...          ...          ...
# 2022-09-26            0            0            0            0
# 2022-09-27            0            0            0            0
# 2022-09-28            0            0            0            0
# 2022-09-29            0            0            0            0
# 2022-09-30            1            0            0            0
#
# [2831 rows x 89 columns]

# %% [markdown]
# # 머신러닝

# %%
LR_model = LinearRegression()
KN_model = KNeighborsRegressor()
Tree_model = DecisionTreeRegressor()
RanF_model = RandomForestRegressor()
xg_model = XGBRegressor()
lg_model = LGBMRegressor()

models = {'LR_model':LR_model,
        'KN_model':KN_model,
        'Tree_model':Tree_model,
        'RanF_model':RanF_model,
        'xg_model':xg_model,
        'lg_model':lg_model}

# %%
results = []
for name, model in models.items():
    print("="*50)
    if model != 'KN_model':
        model.fit(x_train, y_train) # 모델 학습
        y_pred = model.predict(x_test) # 모델 예측
        model_mae = mae(y_test, y_pred)
        model_mape = mape(y_test, y_pred)
        model_r2 = r2_score(y_test, y_pred)
    else:
        model.fit(x_train_s, y_train)
        y_pred = model.predict(x_test_s)
        model_mae = mae(y_test, y_pred)
        model_mape = mape(y_test, y_pred)
        model_r2 = r2_score(y_test, y_pred)
        
    plt.plot(np.array(y_test))
    plt.plot(y_pred)
    plt.show()
    print(name)
    print('MAE:', model_mae)
    print('MAPE:', model_mape)
    print('r2:', model_r2)
    
    results.append([name, (model_mae, model_mape, model_r2)])
# Out:
# ==================================================
# LR_model
# MAE: 5.053185285322601
# MAPE: 1529340416739568.2
# r2: 0.11249606583044691
# ==================================================
# KN_model
# MAE: 5.69891304347826
# MAPE: 1585071260154963.5
# r2: -0.13905171772709735
# ==================================================
# Tree_model
# MAE: 6.501086956521738
# MAPE: 1713325945195297.5
# r2: -0.46050219080941224
# ==================================================
# RanF_model
# MAE: 5.113184782608696
# MAPE: 1545664763415473.5
# r2: 0.08319528401689769
# ==================================================
# xg_model
# MAE: 6.554809989099915
# MAPE: 1478645477494250.0
# r2: -0.29366087363553617
# ==================================================
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2717
# [LightGBM] [Info] Number of data points in the train set: 2831, number of used features: 88
# [LightGBM] [Info] Start training from score 40.202614
# lg_model
# MAE: 5.251531819592938
# MAPE: 1515122737262632.8
# r2: 0.08339720036267806

# %%
sorted(results, key=lambda x: x[1][2])
# Out:
# [['Tree_model', (6.501086956521738, 1713325945195297.5, -0.46050219080941224)],
#  ['xg_model', (6.554809989099915, 1478645477494250.0, -0.29366087363553617)],
#  ['KN_model', (5.69891304347826, 1585071260154963.5, -0.13905171772709735)],
#  ['RanF_model', (5.113184782608696, 1545664763415473.5, 0.08319528401689769)],
#  ['lg_model', (5.251531819592938, 1515122737262632.8, 0.08339720036267806)],
#  ['LR_model', (5.053185285322601, 1529340416739568.2, 0.11249606583044691)]]

# %% [markdown]
# # 딥러닝

# %%
print(f"X shape : {x_train.shape}")
print(f"Y shape : {y_train.shape}")
# Out:
# X shape : (2831, 89)
# Y shape : (2831,)

# %%
# 또 다른 딥러닝 모델
# 입력 레이어 정의
X = tf.keras.Input(shape=[89])

# 은닉 레이어 
H = tf.keras.layers.Dense(256)(X)
H = tf.keras.layers.BatchNormalization()(H)
H = tf.keras.layers.Activation('swish')(H)

# 여기 부분이 skip connection 레이어층 쌓기 부분
for i in range(10):
    H1 = tf.keras.layers.Dropout(0.6)(H)
    H1 = tf.keras.layers.Dense(512)(H1)
    H1 = tf.keras.layers.BatchNormalization()(H1)
    H1 = tf.keras.layers.Activation("ReLU")(H1)
    
    H1 = tf.keras.layers.Dropout(0.6)(H1)
    H1 = tf.keras.layers.Dense(256)(H1)
    H1 = tf.keras.layers.BatchNormalization()(H1)
    H = tf.keras.layers.Add()([H,H1])
    H = tf.keras.layers.Activation("ReLU")(H)

# 출력 레이어 (회귀 모델이므로 활성화 함수는 'linear' 사용)
Y = tf.keras.layers.Dense(1, activation="linear")(H)

# 모델 생성
dp_model = tf.keras.Model(X, Y)
 
# 모델 컴파일 (손실 함수와 평가 지표 수정)
dp_model.compile(loss='mean_squared_error', metrics=['mean_absolute_error'], optimizer = 'Adam')

# 모델 요약
dp_model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_9 (InputLayer)        [(None, 89)]                 0         []
#
#  dense_249 (Dense)           (None, 256)                  23040     ['input_9[0][0]']
#
#  batch_normalization_241 (B  (None, 256)                  1024      ['dense_249[0][0]']
#  atchNormalization)
#
#  activation_241 (Activation  (None, 256)                  0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  dropout_231 (Dropout)       (None, 256)                  0         ['activation_241[0][0]']
#
#  dense_250 (Dense)           (None, 512)                  131584    ['dropout_231[0][0]']
#
#  batch_normalization_242 (B  (None, 512)                  2048      ['dense_250[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 512)                  0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  dropout_232 (Dropout)       (None, 512)                  0         ['activation_242[0][0]']
#
#  dense_251 (Dense)           (None, 256)                  131328    ['dropout_232[0][0]']
#
#  batch_normalization_243 (B  (None, 256)                  1024      ['dense_251[0][0]']
#  atchNormalization)
#
#  add_104 (Add)               (None, 256)                  0         ['activation_241[0][0]',
#                                                                      'batch_normalization_243[0][0
#                                                                     ]']
#
#  activation_243 (Activation  (None, 256)                  0         ['add_104[0][0]']
#  )
#
#  dropout_233 (Dropout)       (None, 256)                  0         ['activation_243[0][0]']
#
#  dense_252 (Dense)           (None, 512)                  131584    ['dropout_233[0][0]']
#
#  batch_normalization_244 (B  (None, 512)                  2048      ['dense_252[0][0]']
#  atchNormalization)
#
#  activation_244 (Activation  (None, 512)                  0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  dropout_234 (Dropout)       (None, 512)                  0         ['activation_244[0][0]']
#
#  dense_253 (Dense)           (None, 256)                  131328    ['dropout_234[0][0]']
#
#  batch_normalization_245 (B  (None, 256)                  1024      ['dense_253[0][0]']
#  atchNormalization)
#
#  add_105 (Add)               (None, 256)                  0         ['activation_243[0][0]',
#                                                                      'batch_normalization_245[0][0
#                                                                     ]']
#
#  activation_245 (Activation  (None, 256)                  0         ['add_105[0][0]']
#  )
#
#  dropout_235 (Dropout)       (None, 256)                  0         ['activation_245[0][0]']
#
#  dense_254 (Dense)           (None, 512)                  131584    ['dropout_235[0][0]']
#
#  batch_normalization_246 (B  (None, 512)                  2048      ['dense_254[0][0]']
#  atchNormalization)
#
#  activation_246 (Activation  (None, 512)                  0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  dropout_236 (Dropout)       (None, 512)                  0         ['activation_246[0][0]']
#
#  dense_255 (Dense)           (None, 256)                  131328    ['dropout_236[0][0]']
#
#  batch_normalization_247 (B  (None, 256)                  1024      ['dense_255[0][0]']
#  atchNormalization)
#
#  add_106 (Add)               (None, 256)                  0         ['activation_245[0][0]',
#                                                                      'batch_normalization_247[0][0
#                                                                     ]']
#
#  activation_247 (Activation  (None, 256)                  0         ['add_106[0][0]']
#  )
#
#  dropout_237 (Dropout)       (None, 256)                  0         ['activation_247[0][0]']
#
#  dense_256 (Dense)           (None, 512)                  131584    ['dropout_237[0][0]']
#
#  batch_normalization_248 (B  (None, 512)                  2048      ['dense_256[0][0]']
#  atchNormalization)
#
#  activation_248 (Activation  (None, 512)                  0         ['batch_normalization_248[0][0
#  )                                                                  ]']
#
#  dropout_238 (Dropout)       (None, 512)                  0         ['activation_248[0][0]']
#
#  dense_257 (Dense)           (None, 256)                  131328    ['dropout_238[0][0]']
#
#  batch_normalization_249 (B  (None, 256)                  1024      ['dense_257[0][0]']
#  atchNormalization)
#
#  add_107 (Add)               (None, 256)                  0         ['activation_247[0][0]',
#                                                                      'batch_normalization_249[0][0
#                                                                     ]']
#
#  activation_249 (Activation  (None, 256)                  0         ['add_107[0][0]']
#  )
#
#  dropout_239 (Dropout)       (None, 256)                  0         ['activation_249[0][0]']
#
#  dense_258 (Dense)           (None, 512)                  131584    ['dropout_239[0][0]']
#
#  batch_normalization_250 (B  (None, 512)                  2048      ['dense_258[0][0]']
#  atchNormalization)
#
#  activation_250 (Activation  (None, 512)                  0         ['batch_normalization_250[0][0
#  )                                                                  ]']
#
#  dropout_240 (Dropout)       (None, 512)                  0         ['activation_250[0][0]']
#
#  dense_259 (Dense)           (None, 256)                  131328    ['dropout_240[0][0]']
#
#  batch_normalization_251 (B  (None, 256)                  1024      ['dense_259[0][0]']
#  atchNormalization)
#
#  add_108 (Add)               (None, 256)                  0         ['activation_249[0][0]',
#                                                                      'batch_normalization_251[0][0
#                                                                     ]']
#
#  activation_251 (Activation  (None, 256)                  0         ['add_108[0][0]']
#  )
#
#  dropout_241 (Dropout)       (None, 256)                  0         ['activation_251[0][0]']
#
#  dense_260 (Dense)           (None, 512)                  131584    ['dropout_241[0][0]']
#
#  batch_normalization_252 (B  (None, 512)                  2048      ['dense_260[0][0]']
#  atchNormalization)
#
#  activation_252 (Activation  (None, 512)                  0         ['batch_normalization_252[0][0
#  )                                                                  ]']
#
#  dropout_242 (Dropout)       (None, 512)                  0         ['activation_252[0][0]']
#
#  dense_261 (Dense)           (None, 256)                  131328    ['dropout_242[0][0]']
#
#  batch_normalization_253 (B  (None, 256)                  1024      ['dense_261[0][0]']
#  atchNormalization)
#
#  add_109 (Add)               (None, 256)                  0         ['activation_251[0][0]',
#                                                                      'batch_normalization_253[0][0
#                                                                     ]']
#
#  activation_253 (Activation  (None, 256)                  0         ['add_109[0][0]']
#  )
#
#  dropout_243 (Dropout)       (None, 256)                  0         ['activation_253[0][0]']
#
#  dense_262 (Dense)           (None, 512)                  131584    ['dropout_243[0][0]']
#
#  batch_normalization_254 (B  (None, 512)                  2048      ['dense_262[0][0]']
#  atchNormalization)
#
#  activation_254 (Activation  (None, 512)                  0         ['batch_normalization_254[0][0
#  )                                                                  ]']
#
#  dropout_244 (Dropout)       (None, 512)                  0         ['activation_254[0][0]']
#
#  dense_263 (Dense)           (None, 256)                  131328    ['dropout_244[0][0]']
#
#  batch_normalization_255 (B  (None, 256)                  1024      ['dense_263[0][0]']
#  atchNormalization)
#
#  add_110 (Add)               (None, 256)                  0         ['activation_253[0][0]',
#                                                                      'batch_normalization_255[0][0
#                                                                     ]']
#
#  activation_255 (Activation  (None, 256)                  0         ['add_110[0][0]']
#  )
#
#  dropout_245 (Dropout)       (None, 256)                  0         ['activation_255[0][0]']
#
#  dense_264 (Dense)           (None, 512)                  131584    ['dropout_245[0][0]']
#
#  batch_normalization_256 (B  (None, 512)                  2048      ['dense_264[0][0]']
#  atchNormalization)
#
#  activation_256 (Activation  (None, 512)                  0         ['batch_normalization_256[0][0
#  )                                                                  ]']
#
#  dropout_246 (Dropout)       (None, 512)                  0         ['activation_256[0][0]']
#
#  dense_265 (Dense)           (None, 256)                  131328    ['dropout_246[0][0]']
#
#  batch_normalization_257 (B  (None, 256)                  1024      ['dense_265[0][0]']
#  atchNormalization)
#
#  add_111 (Add)               (None, 256)                  0         ['activation_255[0][0]',
#                                                                      'batch_normalization_257[0][0
#                                                                     ]']
#
#  activation_257 (Activation  (None, 256)                  0         ['add_111[0][0]']
#  )
#
#  dropout_247 (Dropout)       (None, 256)                  0         ['activation_257[0][0]']
#
#  dense_266 (Dense)           (None, 512)                  131584    ['dropout_247[0][0]']
#
#  batch_normalization_258 (B  (None, 512)                  2048      ['dense_266[0][0]']
#  atchNormalization)
#
#  activation_258 (Activation  (None, 512)                  0         ['batch_normalization_258[0][0
#  )                                                                  ]']
#
#  dropout_248 (Dropout)       (None, 512)                  0         ['activation_258[0][0]']
#
#  dense_267 (Dense)           (None, 256)                  131328    ['dropout_248[0][0]']
#
#  batch_normalization_259 (B  (None, 256)                  1024      ['dense_267[0][0]']
#  atchNormalization)
#
#  add_112 (Add)               (None, 256)                  0         ['activation_257[0][0]',
#                                                                      'batch_normalization_259[0][0
#                                                                     ]']
#
#  activation_259 (Activation  (None, 256)                  0         ['add_112[0][0]']
#  )
#
#  dropout_249 (Dropout)       (None, 256)                  0         ['activation_259[0][0]']
#
#  dense_268 (Dense)           (None, 512)                  131584    ['dropout_249[0][0]']
#
#  batch_normalization_260 (B  (None, 512)                  2048      ['dense_268[0][0]']
#  atchNormalization)
#
#  activation_260 (Activation  (None, 512)                  0         ['batch_normalization_260[0][0
#  )                                                                  ]']
#
#  dropout_250 (Dropout)       (None, 512)                  0         ['activation_260[0][0]']
#
#  dense_269 (Dense)           (None, 256)                  131328    ['dropout_250[0][0]']
#
#  batch_normalization_261 (B  (None, 256)                  1024      ['dense_269[0][0]']
#  atchNormalization)
#
#  add_113 (Add)               (None, 256)                  0         ['activation_259[0][0]',
#                                                                      'batch_normalization_261[0][0
#                                                                     ]']
#
#  activation_261 (Activation  (None, 256)                  0         ['add_113[0][0]']
#  )
#
#  dense_270 (Dense)           (None, 1)                    257       ['activation_261[0][0]']
#
# ==================================================================================================
# Total params: 2684161 (10.24 MB)
# Trainable params: 2668289 (10.18 MB)
# Non-trainable params: 15872 (62.00 KB)
# __________________________________________________________________________________________________

# %%
# 콜백함수 만들기
early = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                                        min_delta = 0, # 이보다 작게 변하면 변한다고 안할거임.
                                        patience = 15, # 이 회수(epoch)동안 개선이 없으면 끝냄
                                        restore_best_weights=True)
# 모델 학습
result = dp_model.fit(x_train, y_train, epochs=1000, batch_size=32, validation_split=0.2, callbacks=[early])
# Out:
# Epoch 1/1000
# 71/71 [==============================] - 13s 58ms/step - loss: 723.0458 - mean_absolute_error: 21.5067 - val_loss: 3381.7002 - val_mean_absolute_error: 38.3138
# Epoch 2/1000
# 71/71 [==============================] - 3s 42ms/step - loss: 167.2473 - mean_absolute_error: 10.0660 - val_loss: 492.3273 - val_mean_absolute_error: 19.8086
# Epoch 3/1000
# 71/71 [==============================] - 3s 44ms/step - loss: 147.2946 - mean_absolute_error: 9.3319 - val_loss: 223.9336 - val_mean_absolute_error: 11.6125
# Epoch 4/1000
# 71/71 [==============================] - 3s 44ms/step - loss: 139.7683 - mean_absolute_error: 9.0224 - val_loss: 114.0917 - val_mean_absolute_error: 7.8487
# Epoch 5/1000
# 71/71 [==============================] - 3s 43ms/step - loss: 134.3657 - mean_absolute_error: 8.7776 - val_loss: 162.9838 - val_mean_absolute_error: 9.7439
# Epoch 6/1000
# 71/71 [==============================] - 3s 48ms/step - loss: 131.3538 - mean_absolute_error: 8.6486 - val_loss: 123.4483 - val_mean_absolute_error: 7.9838
# Epoch 7/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 131.1830 - mean_absolute_error: 8.6283 - val_loss: 70.1891 - val_mean_absolute_error: 6.1620
# Epoch 8/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 129.4047 - mean_absolute_error: 8.6225 - val_loss: 121.3429 - val_mean_absolute_error: 8.8287
# Epoch 9/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 127.1325 - mean_absolute_error: 8.4996 - val_loss: 122.7238 - val_mean_absolute_error: 9.0894
# Epoch 10/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 123.2289 - mean_absolute_error: 8.3287 - val_loss: 111.5256 - val_mean_absolute_error: 8.2777
# Epoch 11/1000
# 71/71 [==============================] - 4s 51ms/step - loss: 110.6520 - mean_absolute_error: 7.8899 - val_loss: 100.8332 - val_mean_absolute_error: 8.0103
# Epoch 12/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 117.7606 - mean_absolute_error: 8.1684 - val_loss: 132.0567 - val_mean_absolute_error: 8.4688
# Epoch 13/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 112.4703 - mean_absolute_error: 7.9721 - val_loss: 102.8754 - val_mean_absolute_error: 7.7656
# Epoch 14/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 119.9120 - mean_absolute_error: 8.3271 - val_loss: 123.2740 - val_mean_absolute_error: 8.7659
# Epoch 15/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 114.3544 - mean_absolute_error: 8.0695 - val_loss: 53.6782 - val_mean_absolute_error: 5.5094
# Epoch 16/1000
# 71/71 [==============================] - 3s 48ms/step - loss: 110.9061 - mean_absolute_error: 7.8555 - val_loss: 60.7578 - val_mean_absolute_error: 5.9990
# Epoch 17/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 110.7830 - mean_absolute_error: 7.9261 - val_loss: 52.7604 - val_mean_absolute_error: 5.5453
# Epoch 18/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 108.1108 - mean_absolute_error: 7.7863 - val_loss: 87.8335 - val_mean_absolute_error: 7.5159
# Epoch 19/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 102.5705 - mean_absolute_error: 7.5398 - val_loss: 89.6504 - val_mean_absolute_error: 7.5348
# Epoch 20/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 104.4343 - mean_absolute_error: 7.6943 - val_loss: 68.0283 - val_mean_absolute_error: 6.4263
# Epoch 21/1000
# 71/71 [==============================] - 3s 48ms/step - loss: 101.7802 - mean_absolute_error: 7.5619 - val_loss: 80.0116 - val_mean_absolute_error: 7.3568
# Epoch 22/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 100.9699 - mean_absolute_error: 7.5420 - val_loss: 52.0969 - val_mean_absolute_error: 5.5830
# Epoch 23/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 107.4237 - mean_absolute_error: 7.7586 - val_loss: 41.0844 - val_mean_absolute_error: 5.0952
# Epoch 24/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 97.7302 - mean_absolute_error: 7.3928 - val_loss: 137.3387 - val_mean_absolute_error: 9.5098
# Epoch 25/1000
# 71/71 [==============================] - 3s 48ms/step - loss: 103.5915 - mean_absolute_error: 7.5976 - val_loss: 81.9328 - val_mean_absolute_error: 6.8499
# Epoch 26/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 107.4346 - mean_absolute_error: 7.7630 - val_loss: 76.4626 - val_mean_absolute_error: 6.7223
# Epoch 27/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 99.7075 - mean_absolute_error: 7.4079 - val_loss: 76.6539 - val_mean_absolute_error: 6.6603
# Epoch 28/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 103.6435 - mean_absolute_error: 7.6114 - val_loss: 62.7481 - val_mean_absolute_error: 5.8727
# Epoch 29/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 102.2634 - mean_absolute_error: 7.5435 - val_loss: 48.7057 - val_mean_absolute_error: 5.3317
# Epoch 30/1000
# 71/71 [==============================] - 3s 49ms/step - loss: 99.0919 - mean_absolute_error: 7.4417 - val_loss: 70.2904 - val_mean_absolute_error: 6.3355
# Epoch 31/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 99.4674 - mean_absolute_error: 7.4514 - val_loss: 172.5108 - val_mean_absolute_error: 10.6584
# Epoch 32/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 102.7461 - mean_absolute_error: 7.5465 - val_loss: 52.2271 - val_mean_absolute_error: 5.4221
# Epoch 33/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 97.4492 - mean_absolute_error: 7.3479 - val_loss: 142.0744 - val_mean_absolute_error: 9.2353
# Epoch 34/1000
# 71/71 [==============================] - 3s 45ms/step - loss: 98.9451 - mean_absolute_error: 7.3770 - val_loss: 48.0806 - val_mean_absolute_error: 5.4393
# Epoch 35/1000
# 71/71 [==============================] - 4s 50ms/step - loss: 98.9066 - mean_absolute_error: 7.3479 - val_loss: 229.6476 - val_mean_absolute_error: 11.9295
# Epoch 36/1000
# 71/71 [==============================] - 3s 47ms/step - loss: 101.3352 - mean_absolute_error: 7.4453 - val_loss: 87.6720 - val_mean_absolute_error: 7.4854
# Epoch 37/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 97.2966 - mean_absolute_error: 7.2821 - val_loss: 81.2602 - val_mean_absolute_error: 6.9262
# Epoch 38/1000
# 71/71 [==============================] - 3s 46ms/step - loss: 98.3269 - mean_absolute_error: 7.3237 - val_loss: 42.4836 - val_mean_absolute_error: 4.9367

# %%
# 모델 평가하기
dp_model.evaluate(x_test, y_test)
# Out:
# 3/3 [==============================] - 0s 12ms/step - loss: 50.6025 - mean_absolute_error: 5.2401
# [50.602474212646484, 5.240072727203369]

# %%
# 예측하기
y_pred = dp_model.predict(x_test)

print('MAE:', mae(y_test, y_pred))
print('MAPE:', mape(y_test, y_pred))
print('r2_score:', r2_score(y_test, y_pred))
# Out:
# 3/3 [==============================] - 0s 9ms/step
# MAE: 5.2400716284047
# MAPE: 1460025673839838.8
# r2_score: 0.11427244190177444

# %%
plt.plot(np.array(y_test))
plt.plot(y_pred)
plt.show()
